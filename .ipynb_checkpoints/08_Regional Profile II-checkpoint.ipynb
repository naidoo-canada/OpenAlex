# %% [markdown]
# # Regional Profile II
#
# #### Updated: Sep 27, 2022

# %% [markdown]
# #

# %% [markdown]
# Generalize regional profile functions:
# - to default to country-level when region not specified
# - to show region-of-interest first author - CA collab, and CA first author - region of interest collab
#
# And, combine search results by concept and title search.

# %%
import pandas as pd
import numpy as np
import ast
import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataDir = '/Users/rnaidoo/Documents/Canada-Secure/GAC/2022_MDRID/Projects_data/OpenAlex/'

# %% [markdown]
# #

# %% [markdown]
# #### Functions:

# %% [markdown]
# Define region:

# %%
def search_institutions(df_pubs, inst_search_terms=[]):
    
    if len(inst_search_terms) > 0 : 
        inst_search_results = []
        for search_term in inst_search_terms:
            inst_search_results = inst_search_results + list(df_pubs.loc[df_pubs['first_auth_inst'].str.contains(search_term)]['first_auth_inst'].unique())
        df_insts = pd.DataFrame({'inst_search': inst_search_results})
        df_pubs2 = df_pubs.merge(df_insts, how='inner', left_on='first_auth_inst', right_on='inst_search')
        
    else:
        inst_search_results = list(df_pubs['first_auth_inst'].unique())
        df_insts = pd.DataFrame({'inst_search': inst_search_results})
        df_pubs2 = df_pubs
        
    return [df_insts, df_pubs2]

# %% [markdown]
# Summarize region:

# %%
def top_institutions(df_pubs, reg_name, top=100, search_query=''):
    
    df_pubs['cited_by_count'] = pd.to_numeric(df_pubs['cited_by_count'])
    df_pubs['publications'] = 1
    
    df_top_inst = df_pubs[['cited_by_count', 'publications', 'first_auth_inst']].groupby(['first_auth_inst']).sum()
    df_top_inst = df_top_inst.sort_values('cited_by_count', ascending=False)
    df_top_inst = df_top_inst.replace(np.nan, '')
    df_top_inst = df_top_inst.rename(columns={
        'cited_by_count': 'by citations',
        'publications': 'by publications'
    })
    if len(df_top_inst) < top:
        top = len(df_top_inst)
    table_title = 'Top-' + str(top) + ' research institutions in ' + reg_name
    if len(search_query) > 0:
        table_title = table_title + " for '" + search_query + "'"
    df_top_inst.index.names = [table_title]
    
    return df_top_inst.head(top)

# %%
def top_researchers(df_pubs, reg_name, top=100, search_query=''):
    
    df_pubs['cited_by_count'] = pd.to_numeric(df_pubs['cited_by_count'])
    df_pubs['publications'] = 1
    
    df_top_ac = df_pubs[['cited_by_count', 'publications', 'first_author']].groupby(['first_author']).sum()
    df_top_ac = df_top_ac.sort_values('cited_by_count', ascending=False)
    df_top_ac2 = df_top_ac.merge(df_pubs[['first_author', 'first_auth_inst', 'first_auth_orcid']], how='left', on='first_author')
    df_top_ac2 = df_top_ac2.replace(np.nan, '')
    df_top_ac2 = df_top_ac2.rename(columns={
        'cited_by_count': 'by citations',
        'publications': 'by publications',
        'first_auth_inst': 'institution',
        'first_auth_orcid': 'orcid'
    })
    df_top_ac2 = df_top_ac2.drop_duplicates(subset=['orcid'])
    df_top_ac2 = df_top_ac2.drop_duplicates(subset=['first_author'])
    df_top_ac2 = df_top_ac2.set_index('first_author')
    if len(df_top_ac2) < top:
        top = len(df_top_ac2)
    table_title = 'Top-' + str(top) + ' academics in ' + reg_name
    if len(search_query) > 0:
        table_title = table_title + " for '" + search_query + "'"
    df_top_ac2.index.names = [table_title]
    
    return df_top_ac2.head(top)

# %% [markdown]
# Explore collaborations:

# %%
def proc_collab(df_in):
    
    for i in range(0, len(df_in)):
        collab_dict_ = df_in['collaborators_of_interest'].iloc[i]
        if collab_dict_ != '{}':
            collab_dict = ast.literal_eval(collab_dict_)
            if len(collab_dict) > 0:
                collab_str = ''
                for auth in collab_dict:
                    if collab_str != '':
                        collab_str += ', '
                    collab_str += auth + ' (' + collab_dict[auth]['col_auth_inst']
                    if collab_dict[auth]['col_auth_orcid'] == None:
                        collab_str += ')'
                    else: 
                        collab_str += ', ' + collab_dict[auth]['col_auth_orcid'] + ')'
                df_in['collaborators_of_interest'].iloc[i] = collab_str
    
    return df_in

# %%
def proc_collab_inv(df_in, reg_insts):
    for i in range(0, len(df_in)):
        collab_dict_ = df_in['collaborators_of_interest'].iloc[i]
        if collab_dict_ != '{}':
            collab_dict = ast.literal_eval(collab_dict_)
            if len(collab_dict) > 0:
                collab_str = ''
                for auth in collab_dict:
                    for reg_inst in reg_insts:
                        if collab_dict[auth]['col_auth_inst'] == reg_inst:
                            if collab_str != '':
                                collab_str += ', '
                            collab_str += auth + ' (' + collab_dict[auth]['col_auth_inst']
                            if collab_dict[auth]['col_auth_orcid'] == None:
                                collab_str += ')'
                            else: 
                                collab_str += ', ' + collab_dict[auth]['col_auth_orcid'] + ')'
                if collab_str == '':
                    collab_str = '{}'
                df_in['collaborators_of_interest'].iloc[i] = collab_str
    
    return df_in

# %%
def write_pubs_by_top_collab(df_result, reg_name, country_code_collab, dataDir_save, inv=False):
    
    df_result = df_result.replace(np.nan, '')
    df_result['collaborators_of_interest'] = df_result['collaborators_of_interest'].replace('{}', 'N')
    df_result = df_result.rename(columns={
        'first_auth_inst': 'Institution',
        'title': 'Publication Title',
        'publication_date': 'Publication Date',
        'cited_by_count': 'Citation Count',
        'first_auth_orcid': 'Academic Profile (ORCID)',
        'id': 'Publication Profile'
    })
    if inv:
        sheet_name_ = 'top-pubs with ' + reg_name + ' collab'
        writer = pd.ExcelWriter(dataDir_save + country_code_collab + '_works_' + reg_name + '_col.xlsx')
        df_result = df_result.rename(columns={
            'first_author': country_code_collab + ' Researcher',
            'collaborators_of_interest': reg_name + ' Collaborators'
        })
    else:        
        sheet_name_ = 'top-pubs with ' + country_code_collab + ' collab'
        writer = pd.ExcelWriter(dataDir_save + reg_name + '_works_' + country_code_collab + '_col.xlsx')
        df_result = df_result.rename(columns={
            'first_author': reg_name + ' Researcher',
            'collaborators_of_interest': country_code_collab + ' Collaborators'
        })    
    df_result.to_excel(writer, sheet_name=sheet_name_, index=False)
    
    # Auto-adjust columns' width
    for column in df_result:
        if column == 'Publication Title':
            column_width = 100
        elif column == country_code_collab + ' Collaborators':
            column_width = 75
        elif column == reg_name + ' Collaborators':
            column_width = 75
        else:
            column_width = max(df_result[column].astype(str).map(len).max(), len(column))
        col_idx = df_result.columns.get_loc(column)
        writer.sheets[sheet_name_].set_column(col_idx, col_idx, column_width)

    writer.save()

# %%
def top_collab_summary_table(df_col, df_pubs, top=100, inv=False, search_query=''):
    
    df_col['publications'] = 1
    df_top_ac = df_col[['cited_by_count', 'publications', 'first_author']].groupby(['first_author']).sum()
    df_top_ac = df_top_ac.sort_values('cited_by_count', ascending=False)
    df_top_ac2 = df_top_ac.merge(df_pubs[['first_author', 'first_auth_inst', 'first_auth_orcid']], how='left', on='first_author')
    df_top_ac2 = df_top_ac2.replace(np.nan, '')
    df_top_ac2 = df_top_ac2.rename(columns={
        'cited_by_count': 'by citations',
        'publications': 'by publications',
        'first_auth_inst': 'institution',
        'first_auth_orcid': 'orcid'
    })
    df_top_ac2 = df_top_ac2.drop_duplicates(subset=['orcid'])
    df_top_ac2 = df_top_ac2.drop_duplicates(subset=['first_author'])
    df_top_ac2 = df_top_ac2.set_index('first_author')
    if len(df_top_ac2) < top:
        top = len(df_top_ac2)
    if inv:
        table_title = 'Top-' + str(top) + ' academics in ' + country_code_collab + ' that collaborated with ' + reg_name + ' researchers'
        if len(search_query) > 0:
            table_title = table_title + ", on \'" + search_query + "'"
        df_top_ac2.index.names = [table_title]        
    else:
        table_title = 'Top-' + str(top) + ' academics in ' + reg_name + ' that collaborated with ' + country_code_collab + ' researchers'
        if len(search_query) > 0:
            table_title = table_title + ", on \'" + search_query + "'"
        df_top_ac2.index.names = [table_title]
            
    return df_top_ac2.head(top)

# %%
def top_collab(df_pubs, reg_name, country_code_collab, dataDir_save, top=100):
    
    df_col = df_pubs.loc[df_pubs['collaborators_of_interest'] != '{}']
    
    df_result = df_col[['first_author', 'first_auth_inst', 'title', 'publication_date', 'cited_by_count', 'collaborators_of_interest', 'first_auth_orcid', 'id']]
    df_result = df_result.sort_values(['cited_by_count', 'publication_date'], ascending=[False, False]).reset_index(drop=True)
    df_result = df_result.drop_duplicates(subset=['id'], keep='first')
    print(str(len(df_result)) + ' unique papers retrieved.')
    
    #Process collaborators of interest
    df_result = proc_collab(df_in=df_result)
    
    #Write results to Excel spreadsheet
    write_pubs_by_top_collab(df_result=df_result, reg_name=reg_name, country_code_collab=country_code_collab, dataDir_save=dataDir_save)
    
    #Produce summary table
    df_top = top_collab_summary_table(df_col=df_col, df_pubs=df_pubs, top=top, inv=False)
    
    return df_top

# %%
def top_collab_inv(df_pubs, reg_name, reg_insts, country_code_collab, dataDir_save, top=100): #reg_insts from df_insts
    
    df_col = df_pubs.loc[df_pubs['collaborators_of_interest'] != '{}']
    df_result = df_col[['first_author', 'first_auth_inst', 'title', 'publication_date', 'cited_by_count', 'collaborators_of_interest', 'first_auth_orcid', 'id']]
    df_result = df_result.sort_values(['cited_by_count', 'publication_date'], ascending=[False, False]).reset_index(drop=True)
    df_col = df_col.drop_duplicates(subset=['id'], keep='first')
    
    #Find the papers where researchers in the region of interest are collaborators
    reg_col_indicies = []
    for i in range(0, len(df_pubs)):
        collab_dict_ = df_pubs['collaborators_of_interest'].iloc[i]
        collab_dict = ast.literal_eval(collab_dict_)
        if len(collab_dict) > 0:
            for auth in collab_dict:
                for reg_inst in reg_insts:
                    if collab_dict[auth]['col_auth_inst'] == reg_inst:
                        reg_col_indicies.append(i) 
    df_col = df_pubs.iloc[reg_col_indicies]
    print(str(len(df_result)) + ' unique papers retrieved.')
    
    #Process collaborators of interest
    df_result = proc_collab_inv(df_in=df_result, reg_insts=reg_insts)
    
    #Write results to Excel spreadsheet
    write_pubs_by_top_collab(df_result=df_result, reg_name=reg_name, country_code_collab=country_code_collab, dataDir_save=dataDir_save, inv=True)    
    
    #Produce summary table
    df_top = top_collab_summary_table(df_col=df_col, df_pubs=df_pubs, top=top, inv=True)
    
    return df_top

# %% [markdown]
# Surface top publications by keywords:

# %%
def search_concepts(search_query, df_concepts):
    
    search_terms = search_query.split(' AND ')
    for i in range(0, len(search_terms)):
        search_terms[i] = search_terms[i].lower()
    print(search_terms)
    for i in range(0, len(search_terms)):
        if i == 0:
            df_search = df_concepts.loc[df_concepts['concept'].str.contains(search_terms[i])]
        else:
            df_search_ = df_concepts.loc[df_concepts['concept'].str.contains(search_terms[i])]
            df_search_ = df_search_.rename(columns={
                'concept': 'concept'+str(i+1),
                'concept_id': 'concept_id'+str(i+1),
                'concept_level': 'concept_level'+str(i+1)
            })
            df_search = df_search.merge(df_search_, how='inner', on='pub_id')
    #print(str(len(df_search)) + ' papers related to search...')
    
    return df_search

# %%
def search_title(search_query, df_pubs, case_sens=False):
    
    df_pubs = df_pubs.fillna('')
    search_terms = search_query.split(' AND ')
    if not case_sens:
        for i in range(0, len(search_terms)):
            search_terms[i] = search_terms[i].lower()
        df_pubs['title'] = df_pubs['title'].str.lower()
    print(search_terms)
    for i in range(0, len(search_terms)):
        if i == 0:
            df_search = df_pubs.loc[df_pubs['title'].str.contains(search_terms[i])]
        else:
            df_search = df_search.loc[df_search['title'].str.contains(search_terms[i])]
    #print(str(len(df_search)) + ' papers related to search...')
    
    return df_search

# %%
def search(search_query, df_concepts, df_pubs, keep_case=False, inv=False, reg_insts=[]):
    
    df_search_conc_ = search_concepts(search_query=search_query, df_concepts=df_concepts)
    df_search_conc = retrieve_papers_byConcept(search_query=search_query, df_search=df_search_conc_, df_pubs=df_pubs, inv=inv, reg_insts=reg_insts)
    
    df_search_titl_ = search_title(search_query=search_query, df_pubs=df_pubs, case_sens=False)
    df_search_titl = retrieve_papers_byTitle(search_query=search_query, df_search=df_search_titl_, inv=inv, reg_insts=reg_insts)
    
    df_search = pd.concat([df_search_conc, df_search_titl])
    df_search = df_search.drop_duplicates(subset=['id'], keep='first')
    print(str(len(df_search)) + ' papers retrieved...')
    df_search = df_search.sort_values(['cited_by_count', 'publication_date'], ascending=[False, False]).reset_index(drop=True)
    
    return df_search

# %%
def retrieve_papers_byConcept(search_query, df_search, df_pubs, inv=False, reg_insts=[]):
    
    df_merge = df_pubs.merge(df_search, left_on='id', right_on='pub_id')
    #print(str(len(df_merge)) + ' papers retrieved...')
    df_result = df_merge[['first_author', 'first_auth_inst', 'concept', 'concept_level', 'title', 'publication_date', 'cited_by_count', 'collaborators_of_interest', 'first_auth_orcid', 'id']]
    df_result = df_result.sort_values(['cited_by_count', 'publication_date', 'concept_level'], ascending=[False, False, False]).reset_index(drop=True)
    df_result = df_result.drop_duplicates(subset=['id'], keep='first')
    #print(str(len(df_result)) + ' unique papers retrieved.')
    df_result = df_result.drop(columns=['concept_level'])
    
    #Process collaborators of interest
    if inv:
        df_result = proc_collab_inv(df_in=df_result, reg_insts=reg_insts)
    else:
        df_result = proc_collab(df_in=df_result)
      
    return df_result

# %%
def retrieve_papers_byTitle(search_query, df_search, inv=False, reg_insts=[]):
    
    #print(str(len(df_search)) + ' papers retrieved...')
    df_result = df_search[['first_author', 'first_auth_inst', 'title', 'publication_date', 'cited_by_count', 'collaborators_of_interest', 'first_auth_orcid', 'id']]
    df_result = df_result.sort_values(['cited_by_count', 'publication_date'], ascending=[False, False]).reset_index(drop=True)
    df_result = df_result.drop_duplicates(subset=['id'], keep='first')
    #print(str(len(df_result)) + ' unique papers retrieved.')
    
    #Process collaborators of interest
    if inv:
        df_result = proc_collab_inv(df_in=df_result, reg_insts=reg_insts)
    else:
        df_result = proc_collab(df_in=df_result)
                
    return df_result

# %%
def write_search_result(search_query, df_result, reg_name, country_code_collab, dataDir_save, inv=False):
    
    sheet_name_ = search_query[0:30]
    df_result = df_result.replace(np.nan, '')
    df_result['collaborators_of_interest'] = df_result['collaborators_of_interest'].replace('{}', 'N')
    df_result = df_result.rename(columns={
        'first_auth_inst': 'Institution',
        'title': 'Publication Title',
        'publication_date': 'Publication Date',
        'cited_by_count': 'Citation Count',
        'first_auth_orcid': 'Academic Profile (ORCID)',
        'id': 'Publication Profile'
    })
    os.makedirs(dataDir_save + 'works_by_search/', exist_ok=True)
    if inv:
        writer = pd.ExcelWriter(dataDir_save + 'works_by_search/' + country_code_collab + '-' + reg_name + '_by_' + search_query + '.xlsx')
        df_result = df_result.rename(columns={
            'first_author': country_code_collab + ' Researcher',
            'collaborators_of_interest': reg_name + ' Collaborators'
        })
    else:
        writer = pd.ExcelWriter(dataDir_save + 'works_by_search/' + reg_name + '-' + country_code_collab + '_by_' + search_query + '.xlsx')
        df_result = df_result.rename(columns={
            'first_author': reg_name + ' Researcher',
            'collaborators_of_interest': country_code_collab + ' Collaborators'
        }) 
    df_result.to_excel(writer, sheet_name=sheet_name_, index=False)
    
    # Auto-adjust columns' width
    for column in df_result:
        if column == 'Publication Title':
            column_width = 100
        elif column == country_code_collab + ' Collaborators':
            column_width = 75
        elif column == reg_name + ' Collaborators':
            column_width = 75
        else:
            column_width = max(df_result[column].astype(str).map(len).max(), len(column))
        col_idx = df_result.columns.get_loc(column)
        writer.sheets[sheet_name_].set_column(col_idx, col_idx, column_width)
        
    writer.save()

# %% [markdown]
# #

# %% [markdown]
# #### Load requisite data:

# %%
country_code = 'ES'
country_code_collab = 'CA'

# %%
df_pubs_A_first_auth = pd.read_csv(dataDir + 'works_' + country_code + '_first_auth/' + country_code_collab + '_col/' + 'works_' + country_code + '_first_auth_' + country_code_collab + '_col_since2017.csv')
print(len(df_pubs_A_first_auth))
df_pubs_A_first_auth.head()
# Out:
# 458602
#                                  id  \
# 0  https://openalex.org/W2963641747
# 1  https://openalex.org/W2472444605
# 2  https://openalex.org/W2478043544
# 3  https://openalex.org/W2482508491
# 4  https://openalex.org/W2484989076
#
#                                                  doi  \
# 0                                                NaN
# 1  https://doi.org/10.1061/(asce)ei.1943-5541.000...
# 2         https://doi.org/10.1016/j.rpsm.2016.04.002
# 3       https://doi.org/10.1016/j.spinee.2016.08.007
# 4        https://doi.org/10.1007/978-3-319-09096-2_9
#
#                                                title  \
# 0  Joan Marcet e Lucía Medina (eds.), La política...
# 1  Developing Topographic Surveying Software to T...
# 2  Inducción de hipocapnia e hiperoxia con maniob...
# 3  Preoperative and postoperative sagittal plane ...
# 4        Looking Into the Profile of Music Audiences
#
#                                         display_name  publication_year  \
# 0  Joan Marcet e Lucía Medina (eds.), La política...              2017
# 1  Developing Topographic Surveying Software to T...              2017
# 2  Inducción de hipocapnia e hiperoxia con maniob...              2017
# 3  Preoperative and postoperative sagittal plane ...              2017
# 4        Looking Into the Profile of Music Audiences              2017
#
#   publication_date                                                ids  \
# 0       2017-01-01  {'openalex': 'https://openalex.org/W2963641747...
# 1       2017-01-01  {'openalex': 'https://openalex.org/W2472444605...
# 2       2017-01-01  {'openalex': 'https://openalex.org/W2478043544...
# 3       2017-01-01  {'openalex': 'https://openalex.org/W2482508491...
# 4       2017-01-01  {'openalex': 'https://openalex.org/W2484989076...
#
#                                           host_venue             type  \
# 0  {'id': None, 'issn_l': None, 'issn': None, 'di...              NaN
# 1  {'id': 'https://openalex.org/V170370859', 'iss...  journal-article
# 2  {'id': 'https://openalex.org/V2898614270', 'is...  journal-article
# 3  {'id': 'https://openalex.org/V112180307', 'iss...  journal-article
# 4  {'id': 'https://openalex.org/V3121261024', 'is...     book-chapter
#
#                                          open_access  ...  \
# 0  {'is_oa': False, 'oa_status': None, 'oa_url': ...  ...
# 1  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 2  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 3  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 4  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
#
#                              abstract_inverted_index  \
# 0                                                NaN
# 1  {'AbstractIn': [0], 'this': [1], 'study,': [2]...
# 2  {'Resumen': [0], 'Introduccion': [3], 'La': [5...
# 3  {'Abstract': [0], 'Background': [3], 'Context'...
# 4  {'The': [0], 'main': [1, 98], 'aims': [2], 'of...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0                                                 []
# 1  [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 2  [{'year': 2021, 'cited_by_count': 1}, {'year':...
# 3  [{'year': 2021, 'cited_by_count': 2}, {'year':...
# 4  [{'year': 2022, 'cited_by_count': 1}, {'year':...
#
#                  updated_date created_date             first_author  \
# 0  2022-08-08T10:54:07.500056   2019-07-30             Steven Forti
# 1  2022-08-09T14:16:07.295905   2016-07-22     Miguel Castro-García
# 2  2022-08-22T06:24:56.670484   2016-08-23     Aida de Arriba-Arnau
# 3                  2022-06-24   2016-08-23  Felisa Sánchez-Mariscal
# 4  2022-08-08T13:09:36.373379   2016-08-23  Víctor Fernández-Blanco
#
#                         first_auth_orcid                   first_auth_inst  \
# 0  https://orcid.org/0000-0002-7027-0220             Instituto de Historia
# 1  https://orcid.org/0000-0003-4157-6164  University of Castilla-La Mancha
# 2  https://orcid.org/0000-0002-7877-7341           University of Barcelona
# 3                                    NaN  Hospital Universitario de Getafe
# 4  https://orcid.org/0000-0003-2096-9460              University of Oviedo
#
#   first_auth_country collaborators_of_interest
# 0                 ES                        {}
# 1                 ES                        {}
# 2                 ES                        {}
# 3                 ES                        {}
# 4                 ES                        {}
#
# [5 rows x 31 columns]

# %%
df_pubs_B_first_auth = pd.read_csv(dataDir + 'works_' + country_code_collab + '_first_auth/' + country_code + '_col/' + 'works_' + country_code_collab + '_first_auth_' + country_code + '_col_since2017.csv')
print(len(df_pubs_B_first_auth))
df_pubs_B_first_auth.head()
# Out:
# 506581
#                                  id  \
# 0  https://openalex.org/W2582434976
# 1  https://openalex.org/W2598730797
# 2  https://openalex.org/W2523535834
# 3  https://openalex.org/W2940082676
# 4  https://openalex.org/W2732588845
#
#                                             doi  \
# 0  https://doi.org/10.1007/978-1-4842-2598-1_12
# 1    https://doi.org/10.1109/iccnc.2017.7876167
# 2   https://doi.org/10.1007/978-3-319-42304-3_1
# 3                                           NaN
# 4  https://doi.org/10.1161/strokeaha.117.017622
#
#                                                title  \
# 0                              Using Resource Quotas
# 1  An improved SDN-based fabric for flexible data...
# 2  Power-Shaping Configurable Microprocessors for...
# 3  Les contours de l'organisation du travail soum...
# 4                             In-Patient Code Stroke
#
#                                         display_name  publication_year  \
# 0                              Using Resource Quotas              2017
# 1  An improved SDN-based fabric for flexible data...              2017
# 2  Power-Shaping Configurable Microprocessors for...              2017
# 3  Les contours de l'organisation du travail soum...              2017
# 4                             In-Patient Code Stroke              2017
#
#   publication_date                                                ids  \
# 0       2017-01-01  {'openalex': 'https://openalex.org/W2582434976...
# 1       2017-01-01  {'openalex': 'https://openalex.org/W2598730797...
# 2       2017-01-01  {'openalex': 'https://openalex.org/W2523535834...
# 3       2017-01-01  {'openalex': 'https://openalex.org/W2940082676...
# 4       2017-01-01  {'openalex': 'https://openalex.org/W2732588845...
#
#                                           host_venue                 type  \
# 0  {'id': None, 'issn_l': None, 'issn': None, 'di...         book-chapter
# 1  {'id': None, 'issn_l': None, 'issn': None, 'di...  proceedings-article
# 2  {'id': None, 'issn_l': None, 'issn': None, 'di...         book-chapter
# 3  {'id': None, 'issn_l': None, 'issn': None, 'di...                  NaN
# 4  {'id': 'https://openalex.org/V62532593', 'issn...      journal-article
#
#                                          open_access  ...  \
# 0  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 1  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 2  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 3  {'is_oa': False, 'oa_status': None, 'oa_url': ...  ...
# 4  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...  ...
#
#                              abstract_inverted_index  \
# 0  {'In': [0], 'Chapter': [1], '10': [2], 'we': [...
# 1  {'Data': [0], 'centers': [1], 'play': [2], 'an...
# 2  {'The': [0], '“Internet': [1], 'of': [2, 8, 52...
# 3                                                NaN
# 4  {'Stroke': [0], 'is': [1], 'a': [2], 'relative...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0                                                 []
# 1              [{'year': 2020, 'cited_by_count': 1}]
# 2                                                 []
# 3                                                 []
# 4  [{'year': 2022, 'cited_by_count': 5}, {'year':...
#
#                  updated_date created_date            first_author  \
# 0                  2022-06-30   2017-02-03            Deepak Vohra
# 1  2022-08-22T07:21:54.950801   2017-04-07                 Wei Hou
# 2  2022-08-18T08:44:40.666311   2016-09-30             Fabio Campi
# 3  2022-08-07T09:01:08.519143   2019-04-25             Marc Nihoul
# 4  2022-08-30T10:39:20.384673   2017-07-14  Charles D. Kassardjian
#
#                         first_auth_orcid                  first_auth_inst  \
# 0                                    NaN              Peace Arch Hospital
# 1                                    NaN             University of Ottawa
# 2                                    NaN          Simon Fraser University
# 3                                    NaN  Université Laval Faculty of Law
# 4  https://orcid.org/0000-0001-7117-8787            University of Toronto
#
#   first_auth_country collaborators_of_interest
# 0                 CA                        {}
# 1                 CA                        {}
# 2                 CA                        {}
# 3                 CA                        {}
# 4                 CA                        {}
#
# [5 rows x 31 columns]

# %%
df_conc_A_first_auth = pd.read_csv(dataDir + 'works_' + country_code + '_first_auth/' + 'concepts_by_pub_' + country_code + '_first_auth_since2017.csv')
df_conc_A_first_auth
# Out:
#                                    pub_id                        concept  \
# 0        https://openalex.org/W2963641747              political science
# 1        https://openalex.org/W2784174820              political science
# 2        https://openalex.org/W3042865676                      sociology
# 3        https://openalex.org/W2783557752                       medicine
# 4        https://openalex.org/W3042865676                     psychology
# ...                                   ...                            ...
# 3282464  https://openalex.org/W3048970145                metapneumovirus
# 3282465  https://openalex.org/W3112118800            cell-free fetal dna
# 3282466  https://openalex.org/W3083927243       transimpedance amplifier
# 3282467  https://openalex.org/W2990774577                autotransformer
# 3282468  https://openalex.org/W3088816417  magnetocrystalline anisotropy
#
#                                concept_id  concept_level
# 0          https://openalex.org/C17744445              0
# 1          https://openalex.org/C17744445              0
# 2         https://openalex.org/C144024400              0
# 3          https://openalex.org/C71924100              0
# 4          https://openalex.org/C15744967              0
# ...                                   ...            ...
# 3282464  https://openalex.org/C2911218186              5
# 3282465   https://openalex.org/C152110520              5
# 3282466    https://openalex.org/C92631468              5
# 3282467    https://openalex.org/C22958824              5
# 3282468    https://openalex.org/C56803174              5
#
# [3282469 rows x 4 columns]

# %%
df_conc_B_first_auth = pd.read_csv(dataDir + 'works_' + country_code_collab + '_first_auth/' + 'concepts_by_pub_' + country_code_collab + '_first_auth_since2017.csv')
df_conc_B_first_auth
# Out:
#                                    pub_id  \
# 0        https://openalex.org/W3039684518
# 1        https://openalex.org/W2807818210
# 2        https://openalex.org/W2794919000
# 3        https://openalex.org/W2807748811
# 4        https://openalex.org/W3132079119
# ...                                   ...
# 3899125  https://openalex.org/W2914470466
# 3899126  https://openalex.org/W3083331412
# 3899127  https://openalex.org/W4238312086
# 3899128  https://openalex.org/W2943641736
# 3899129  https://openalex.org/W3045288344
#
#                                                    concept  \
# 0                                                sociology
# 1                                                 medicine
# 2                                                 medicine
# 3                                                 medicine
# 4                                                 business
# ...                                                    ...
# 3899125                                     audit evidence
# 3899126  severe acute respiratory syndrome coronavirus ...
# 3899127                                  rna polymerase ii
# 3899128                                         ice tongue
# 3899129                                           pandemic
#
#                                concept_id  concept_level
# 0         https://openalex.org/C144024400              0
# 1          https://openalex.org/C71924100              0
# 2          https://openalex.org/C71924100              0
# 3          https://openalex.org/C71924100              0
# 4         https://openalex.org/C144133560              0
# ...                                   ...            ...
# 3899125   https://openalex.org/C156223087              5
# 3899126  https://openalex.org/C3007834351              5
# 3899127    https://openalex.org/C64350747              5
# 3899128    https://openalex.org/C24474704              5
# 3899129    https://openalex.org/C89623803              5
#
# [3899130 rows x 4 columns]

# %% [markdown]
# #

# %% [markdown]
# #### Specify a region of interest (if necessary):

# %%
reg_name = 'IE University'

if reg_name != '':
    dataDir_reg = dataDir+'works_' + country_code + '_first_auth/' + country_code_collab + '_col/Regional/' + reg_name + '/'
    os.makedirs(dataDir_reg, exist_ok=True)
else:
    dataDir_reg = dataDir+'works_' + country_code + '_first_auth/' + country_code_collab + '_col/'
    reg_name = country_code

# %% [markdown]
# Search for institutions:

# %%
inst_search_terms = [    
    'IE'
    #Madrid
    
    #Barcelona
    #'Barc',
    #'Cata'
    
    #Scotland
    #'Scot',
    #'St Andrews',
    #'Edin',
    #'Glasg',
    #'Aberdeen',
    #'Strathclyde',
    #'Dundee'
]

df_insts, df_pubs_reg = search_institutions(df_pubs=df_pubs_A_first_auth, inst_search_terms=inst_search_terms)
reg_insts = df_insts['inst_search'].unique()
reg_insts
# Out:
# array(['IE University'], dtype=object)

# %%
len(reg_insts)
# Out:
# 1

# %% [markdown]
# #### What are the top institutions in the region?

# %%
top_institutions(df_pubs=df_pubs_reg, reg_name=reg_name, top=10)
# Out:
#                                       by citations  by publications
# Top-10 research institutions in ES
# University of Barcelona                     101716            14966
# University of Granada                        78646            13679
# Autonomous University of Barcelona           77377            13940
# Complutense University of Madrid             75243            16730
# University of the Basque Country             71251            10999
# University of Valencia                       66985            13342
# University of Seville                        60228            12576
# Autonomous University of Madrid              57436            10015
# Universitat Politècnica de València          48741             9323
# Universitat Politècnica de Catalunya         45785             7894

# %% [markdown]
# #### Who are the top researchers in the region, overall?

# %%
top_researchers(df_pubs=df_pubs_reg, reg_name=reg_name, top=10)
# Out:
#                          by citations  by publications  \
# Top-10 academics in ES
# Alfonso J. Cruz-Jentoft          4045               13
# Luis Paz-Ares                    3503               50
# Lichen Liu                       3277               19
# Daniele V.F. Tauriello           2709                5
# Jordi Bruix                      2456               12
# Julio Rozas                      2149                1
# Heng Zhang                       1974               18
# Jeffrey V. Lazarus               1942               45
# Eduard Batlle                    1914                2
# Joan B. Soriano                  1766               35
#
#                                                                institution  \
# Top-10 academics in ES
# Alfonso J. Cruz-Jentoft               Hospital Universitario Ramón y Cajal
# Luis Paz-Ares            Centro Nacional de Investigaciones Cardiovascu...
# Lichen Liu                                 Instituto de Tecnología Química
# Daniele V.F. Tauriello               Institute for Research in Biomedicine
# Jordi Bruix                                   Hospital Clínic de Barcelona
# Julio Rozas                                        University of Barcelona
# Heng Zhang                                                  CIC energigune
# Jeffrey V. Lazarus                   Barcelona Institute for Global Health
# Eduard Batlle            Institució Catalana de Recerca i Estudis Avançats
# Joan B. Soriano                            Autonomous University of Madrid
#
#                                                          orcid
# Top-10 academics in ES
# Alfonso J. Cruz-Jentoft  https://orcid.org/0000-0001-7628-4861
# Luis Paz-Ares            https://orcid.org/0000-0002-1947-3364
# Lichen Liu               https://orcid.org/0000-0001-5067-0481
# Daniele V.F. Tauriello   https://orcid.org/0000-0003-1522-3496
# Jordi Bruix              https://orcid.org/0000-0002-9826-0753
# Julio Rozas              https://orcid.org/0000-0002-6839-9148
# Heng Zhang               https://orcid.org/0000-0002-8811-6336
# Jeffrey V. Lazarus       https://orcid.org/0000-0001-9618-2299
# Eduard Batlle            https://orcid.org/0000-0003-2422-0326
# Joan B. Soriano          https://orcid.org/0000-0001-9740-2994

# %% [markdown]
# #### Who are the top collaborators between the region of interest and the other country of interest, overall?

# %%
top_collab(df_pubs=df_pubs_reg, reg_name=reg_name, country_code_collab=country_code_collab, dataDir_save=dataDir_reg, top=10)
# Out:
# 3740 unique papers retrieved.
#                                                     by citations  \
# Top-10 academics in ES that collaborated with C...
# Luis Paz-Ares                                               2197
# Xavier Montalban                                             928
# Unai Pascual                                                 764
# Antonio González-Martín                                      674
# Aurelio Tobias                                               431
# Joan B. Soriano                                              378
# Elena Sánchez-López                                          344
# Miguel Martin                                                323
# Carol Moreno                                                 310
# Julián Panés                                                 262
#
#                                                     by publications  \
# Top-10 academics in ES that collaborated with C...
# Luis Paz-Ares                                                     8
# Xavier Montalban                                                  2
# Unai Pascual                                                      2
# Antonio González-Martín                                           3
# Aurelio Tobias                                                    1
# Joan B. Soriano                                                   2
# Elena Sánchez-López                                               1
# Miguel Martin                                                     1
# Carol Moreno                                                      2
# Julián Panés                                                      4
#
#                                                                                           institution  \
# Top-10 academics in ES that collaborated with C...
# Luis Paz-Ares                                       Centro Nacional de Investigaciones Cardiovascu...
# Xavier Montalban                                                  Vall d'Hebron Hospital Universitari
# Unai Pascual                                                         University of the Basque Country
# Antonio González-Martín                                                Clinica Universidad de Navarra
# Aurelio Tobias                                      Institute of Environmental Assessment and Wate...
# Joan B. Soriano                                                       Autonomous University of Madrid
# Elena Sánchez-López                                                           University of Barcelona
# Miguel Martin                                         Hospital General Universitario Gregorio Marañón
# Carol Moreno                                                       Autonomous University of Barcelona
# Julián Panés                                        Centro de Investigación Biomédica en Red de En...
#
#                                                                                     orcid
# Top-10 academics in ES that collaborated with C...
# Luis Paz-Ares                                       https://orcid.org/0000-0002-1947-3364
# Xavier Montalban                                    https://orcid.org/0000-0002-0098-9918
# Unai Pascual                                        https://orcid.org/0000-0002-5696-236X
# Antonio González-Martín                             https://orcid.org/0000-0001-8376-9576
# Aurelio Tobias                                      https://orcid.org/0000-0001-6428-6755
# Joan B. Soriano                                     https://orcid.org/0000-0001-9740-2994
# Elena Sánchez-López                                 https://orcid.org/0000-0001-8546-766X
# Miguel Martin                                       https://orcid.org/0000-0001-6156-0739
# Carol Moreno                                        https://orcid.org/0000-0003-3275-0271
# Julián Panés                                        https://orcid.org/0000-0002-4971-6902

# %%
top_collab_inv(df_pubs=df_pubs_B_first_auth, reg_name=reg_name, reg_insts=reg_insts, country_code_collab=country_code_collab, dataDir_save=dataDir_reg, top=10)
# Out:
# 3504 unique papers retrieved.
#                                                     by citations  \
# Top-10 academics in CA that collaborated with E...
# Gregory B. Gloor                                            1990
# Yash Patel                                                  1280
# Josep Rodés-Cabau                                           1238
# Deborah J. Cook                                             1186
# Jacob Biamonte                                              1169
# Sina M. Adl                                                 1106
# Jean-Claude Tardif                                          1083
# Deepali Kumar                                                999
# Denice S. Feig                                               943
# Jan Brozek                                                   753
#
#                                                     by publications  \
# Top-10 academics in CA that collaborated with E...
# Gregory B. Gloor                                                  2
# Yash Patel                                                       46
# Josep Rodés-Cabau                                                19
# Deborah J. Cook                                                   2
# Jacob Biamonte                                                    1
# Sina M. Adl                                                       2
# Jean-Claude Tardif                                                2
# Deepali Kumar                                                    10
# Denice S. Feig                                                    5
# Jan Brozek                                                        3
#
#                                                                                        institution  \
# Top-10 academics in CA that collaborated with E...
# Gregory B. Gloor                                                                Western University
# Yash Patel                                          Holland Bloorview Kids Rehabilitation Hospital
# Josep Rodés-Cabau                                                                 Université Laval
# Deborah J. Cook                                                                McMaster University
# Jacob Biamonte                                                              University of Waterloo
# Sina M. Adl                                                             University of Saskatchewan
# Jean-Claude Tardif                                                        Montreal Heart Institute
# Deepali Kumar                                                            University Health Network
# Denice S. Feig                                                               University of Toronto
# Jan Brozek                                                                     McMaster University
#
#                                                                                     orcid
# Top-10 academics in CA that collaborated with E...
# Gregory B. Gloor                                    https://orcid.org/0000-0001-5803-3380
# Yash Patel
# Josep Rodés-Cabau                                   https://orcid.org/0000-0001-8237-7095
# Deborah J. Cook                                     https://orcid.org/0000-0002-4087-543X
# Jacob Biamonte                                      https://orcid.org/0000-0002-0590-3327
# Sina M. Adl                                         https://orcid.org/0000-0001-6324-6065
# Jean-Claude Tardif                                  https://orcid.org/0000-0002-8200-8983
# Deepali Kumar                                       https://orcid.org/0000-0003-1961-0477
# Denice S. Feig                                      https://orcid.org/0000-0001-8561-7584
# Jan Brozek                                          https://orcid.org/0000-0002-3122-0773

# %% [markdown]
# #

# %% [markdown]
# #### Search for the top researchers and collaborations, for a particular subject by keywords:

# %%
search_query = 'marketing'

# %% [markdown]
# Region of interest from country A first author, country B collaborator:

# %%
df_search = search(search_query=search_query, df_concepts=df_conc_A_first_auth, df_pubs=df_pubs_reg)
# Out:
# ['marketing']
# ['marketing']
# 50 papers retrieved...

# %%
df_search.head()
# Out:
#         first_author first_auth_inst    concept  \
# 0     Mikko Ketokivi   IE University  marketing
# 1      Elena Revilla   IE University  marketing
# 2  Stefanie Beninger   IE University  marketing
# 3      Rosario Silva   IE University  marketing
# 4     Serghei Musaji   IE University  marketing
#
#                                                title publication_date  \
# 0  Why locate manufacturing in a high-cost countr...       2017-03-01
# 1  Bulding ambidexterity through creativity mecha...       2018-11-01
# 2  Collective market shaping by competitors and i...       2021-01-01
# 3  Corporate brand and hotel performance: A resou...       2017-10-01
# 4  How Long Does It Take to Get to the Learning C...       2020-02-13
#
#    cited_by_count                          collaborators_of_interest  \
# 0              66                                                 {}
# 1              28                                                 {}
# 2              16  June N.P. Francis (Simon Fraser University, ht...
# 3              13                                                 {}
# 4              11                                                 {}
#
#                         first_auth_orcid                                id
# 0  https://orcid.org/0000-0003-4510-4949  https://openalex.org/W2580589104
# 1  https://orcid.org/0000-0002-9901-8707  https://openalex.org/W2805812250
# 2  https://orcid.org/0000-0002-6956-7625  https://openalex.org/W3087471450
# 3                                    NaN  https://openalex.org/W2620514704
# 4                                    NaN  https://openalex.org/W2913295851

# %%
write_search_result(search_query=search_query, df_result=df_search, reg_name=reg_name, country_code_collab=country_code_collab, dataDir_save=dataDir_reg, inv=False)

# %%
top_institutions(df_pubs=df_search, reg_name=reg_name, top=10, search_query=search_query)
# Out:
#                                                     by citations  \
# Top-10 research institutions in ES for 'quantum...
# Institute of Photonic Sciences                               533
# University of the Basque Country                             376
# Institute for High Energy Physics                            350
# University of Valencia                                       316
# Universidade de Vigo                                         277
# Barcelona Supercomputing Center                              219
# Donostia International Physics Center                        167
# Autonomous University of Madrid                              143
# University of A Coruña                                       115
# Technical University of Madrid                                75
#
#                                                     by publications
# Top-10 research institutions in ES for 'quantum...
# Institute of Photonic Sciences                                   15
# University of the Basque Country                                 24
# Institute for High Energy Physics                                 1
# University of Valencia                                            7
# Universidade de Vigo                                              4
# Barcelona Supercomputing Center                                   7
# Donostia International Physics Center                             3
# Autonomous University of Madrid                                   8
# University of A Coruña                                            7
# Technical University of Madrid                                   19

# %%
top_researchers(df_pubs=df_search, reg_name=reg_name, top=10, search_query=search_query)
# Out:
#                                            by citations  by publications  \
# Top-10 academics in ES for 'quantum comp'
# P. Forn-Díaz                                        378                2
# Alejandro Gaita-Ariño                               279                1
# Miguel Herrero-Collantes                            271                1
# Antonio Acín                                        245                1
# Roman Orus                                          167                3
# Lucas Lamata                                        158                6
# Tiago M. Fernández-Caramés                          110                2
# Elsa Prada                                          109                1
# Adrián Pérez-Salinas                                 98                2
# Nicolas Maring                                       80                1
#
#                                                                      institution  \
# Top-10 academics in ES for 'quantum comp'
# P. Forn-Díaz                                   Institute for High Energy Physics
# Alejandro Gaita-Ariño                                     University of Valencia
# Miguel Herrero-Collantes                                    Universidade de Vigo
# Antonio Acín                                      Institute of Photonic Sciences
# Roman Orus                                 Donostia International Physics Center
# Lucas Lamata                                    University of the Basque Country
# Tiago M. Fernández-Caramés                                University of A Coruña
# Elsa Prada                                       Autonomous University of Madrid
# Adrián Pérez-Salinas                             Barcelona Supercomputing Center
# Nicolas Maring                                    Institute of Photonic Sciences
#
#                                                                            orcid
# Top-10 academics in ES for 'quantum comp'
# P. Forn-Díaz                               https://orcid.org/0000-0003-4365-5157
# Alejandro Gaita-Ariño                      https://orcid.org/0000-0002-1600-8627
# Miguel Herrero-Collantes
# Antonio Acín                               https://orcid.org/0000-0002-1355-3435
# Roman Orus                                 https://orcid.org/0000-0002-4496-8115
# Lucas Lamata                               https://orcid.org/0000-0002-9504-8685
# Tiago M. Fernández-Caramés                 https://orcid.org/0000-0003-2179-5917
# Elsa Prada                                 https://orcid.org/0000-0001-7522-4795
# Adrián Pérez-Salinas                       https://orcid.org/0000-0001-5430-6468
# Nicolas Maring                             https://orcid.org/0000-0001-7915-9986

# %%
df_col = df_search.loc[df_search['collaborators_of_interest'] != '{}']
top_collab_summary_table(df_col=df_col, df_pubs=df_search, search_query=search_query, top=10, inv=False)
# Out:
#                                                     by citations  \
# Top-5 academics in ES that collaborated with CA...
# Ding Liu                                                      49
# P. Forn-Díaz                                                  28
# Juan Carlos Garcia-Escartin                                    5
# M. Mochol-Grzelak                                              4
# Lian-Ao Wu                                                     1
#
#                                                     by publications  \
# Top-5 academics in ES that collaborated with CA...
# Ding Liu                                                          1
# P. Forn-Díaz                                                      1
# Juan Carlos Garcia-Escartin                                       1
# M. Mochol-Grzelak                                                 1
# Lian-Ao Wu                                                        1
#
#                                                                           institution  \
# Top-5 academics in ES that collaborated with CA...
# Ding Liu                                               Institute of Photonic Sciences
# P. Forn-Díaz                                        Institute for High Energy Physics
# Juan Carlos Garcia-Escartin                                  University of Valladolid
# M. Mochol-Grzelak                                      Institute of Photonic Sciences
# Lian-Ao Wu                                           University of the Basque Country
#
#                                                                                     orcid
# Top-5 academics in ES that collaborated with CA...
# Ding Liu                                            https://orcid.org/0000-0001-7688-8200
# P. Forn-Díaz                                        https://orcid.org/0000-0003-4365-5157
# Juan Carlos Garcia-Escartin                         https://orcid.org/0000-0002-9813-5004
# M. Mochol-Grzelak
# Lian-Ao Wu                                          https://orcid.org/0000-0003-4896-6958

# %% [markdown]
# Country B first author, region of interest from Country A collaborator:

# %%
df_search = search(search_query=search_query, df_concepts=df_conc_B_first_auth, df_pubs=df_pubs_B_first_auth, inv=True, reg_insts=reg_insts)
# Out:
# ['quantum comp']
# ['quantum comp']
# 305 papers retrieved...

# %%
write_search_result(search_query=search_query, df_result=df_search, reg_name=reg_name, country_code_collab=country_code_collab, dataDir_save=dataDir_reg, inv=True)

# %%
df_col = df_search.loc[df_search['collaborators_of_interest'] != '{}']
top_collab_summary_table(df_col=df_col, df_pubs=df_search, search_query=search_query, top=10, inv=True)
# Out:
#                                                     by citations  \
# Top-7 academics in CA that collaborated with ES...
# Jacob Biamonte                                              1169
# Scott Ryall                                                   28
# Samuel Boutin                                                 25
# Danny Paulson                                                 19
# Angus Lowe                                                    10
# Javad Pourahmadazar                                            4
# Zi-Wen Liu                                                     2
#
#                                                     by publications  \
# Top-7 academics in CA that collaborated with ES...
# Jacob Biamonte                                                    1
# Scott Ryall                                                       1
# Samuel Boutin                                                     1
# Danny Paulson                                                     1
# Angus Lowe                                                        1
# Javad Pourahmadazar                                               1
# Zi-Wen Liu                                                        1
#
#                                                                                        institution  \
# Top-7 academics in CA that collaborated with ES...
# Jacob Biamonte                                                              University of Waterloo
# Scott Ryall                                                             Hospital for Sick Children
# Samuel Boutin                                                             Université de Sherbrooke
# Danny Paulson                                                               University of Waterloo
# Angus Lowe                                                                  University of Waterloo
# Javad Pourahmadazar                                 Institut National de la Recherche Scientifique
# Zi-Wen Liu                                                                     Perimeter Institute
#
#                                                                                     orcid
# Top-7 academics in CA that collaborated with ES...
# Jacob Biamonte                                      https://orcid.org/0000-0002-0590-3327
# Scott Ryall                                         https://orcid.org/0000-0002-5327-3892
# Samuel Boutin                                       https://orcid.org/0000-0003-3819-6830
# Danny Paulson                                       https://orcid.org/0000-0003-2522-4046
# Angus Lowe
# Javad Pourahmadazar                                 https://orcid.org/0000-0002-2121-6965
# Zi-Wen Liu                                          https://orcid.org/0000-0002-3402-9763
