# %% [markdown]
# # Analyze Canada-Spain Academic Publications II
#
# #### Updated: Sep 12, 2022

# %% [markdown]
# #

# %% [markdown]
# Unpack and surface concepts data for each publication. Identify Spanish experts in key areas of interest to GAC-MDRID.

# %%
import pandas as pd
import numpy as np
import ast
import requests
import time
import os

# %%
dataDir = '/Users/rnaidoo/Documents/Canada-Secure/GAC/2022_MDRID/Projects_data/OpenAlex/'

# %% [markdown]
# #

# %% [markdown]
# #### Functions:

# %%
def construct_query_string_cursor(endpoint, filters, cursor='*'):
    
    filter_param = f'filter={",".join(filters)}'
    filtered_works_url = f'https://api.openalex.org/{endpoint}?mailto=naidoo@ualberta.ca&{filter_param}&per-page=200&cursor={cursor}'
    print(filtered_works_url)
    
    return filtered_works_url

# %%
def isolate_esp_first_auth_pubs(df_resp):

    esp_first_indicies = []
    for i in range(0, len(df_resp)):
        authorships_dict = df_resp['authorships'][i]
        for j in range(0, len(authorships_dict)):
            if authorships_dict[j]['author_position'] == 'first': 
                first_auth_insts = authorships_dict[j]['institutions']
                if len(first_auth_insts) > 0:
                    for k in range(0, len(first_auth_insts)): 
                        if len(first_auth_insts[k]) > 0:
                            if first_auth_insts[k]['country_code'] == 'ES':
                                esp_first_indicies.append(i)
                        
    df_esp_first = df_resp.iloc[esp_first_indicies]
    
    return df_esp_first

# %% [markdown]
# #

# %% [markdown]
# #### Find publications with concepts relevant to foreign policy and Canada-Spain relations - Canada-Spain first author + collaborator subset:

# %% [markdown]
# Combine Canadian and Spanish first-author publications:

# %%
df_can = pd.read_csv(dataDir + 'works_can_first_auth_esp_col_proc.csv')
df_esp = pd.read_csv(dataDir + 'works_esp_first_auth_can_col_proc.csv')
df_tot = pd.concat([df_can, df_esp]).sort_values('cited_by_count', ascending=False)
print(len(df_tot))
df_tot.head()
# Out:
# 118
#                                  id  \
# 0  https://openalex.org/W2277258071
# 1  https://openalex.org/W2112455323
# 2  https://openalex.org/W2467227824
# 0  https://openalex.org/W2280783985
# 1  https://openalex.org/W2116358746
#
#                                              doi  \
# 0  https://doi.org/10.1016/s0140-6736(16)00163-x
# 1              https://doi.org/10.1002/mds.26424
# 2          https://doi.org/10.1038/kisup.2012.73
# 0  https://doi.org/10.1016/s1474-4422(15)00401-9
# 1          https://doi.org/10.1093/gerona/gls119
#
#                                                title  \
# 0  Endovascular thrombectomy after large-vessel i...
# 1  MDS clinical diagnostic criteria for Parkinson...
# 2                                             Notice
# 0  A clinical approach to diagnosis of autoimmune...
# 1  Searching for an Operational Definition of Fra...
#
#                                         display_name  publication_year  \
# 0  Endovascular thrombectomy after large-vessel i...              2016
# 1  MDS clinical diagnostic criteria for Parkinson...              2015
# 2                                             Notice              2013
# 0  A clinical approach to diagnosis of autoimmune...              2016
# 1  Searching for an Operational Definition of Fra...              2013
#
#   publication_date                                                ids  \
# 0       2016-04-23  {'openalex': 'https://openalex.org/W2277258071...
# 1       2015-10-01  {'openalex': 'https://openalex.org/W2112455323...
# 2       2013-01-01  {'openalex': 'https://openalex.org/W2467227824...
# 0       2016-04-01  {'openalex': 'https://openalex.org/W2280783985...
# 1       2013-01-01  {'openalex': 'https://openalex.org/W2116358746...
#
#                                           host_venue             type  \
# 0  {'id': 'https://openalex.org/V49861241', 'issn...  journal-article
# 1  {'id': 'https://openalex.org/V163027424', 'iss...  journal-article
# 2  {'id': 'https://openalex.org/V4210177655', 'is...  journal-article
# 0  {'id': 'https://openalex.org/V70053155', 'issn...  journal-article
# 1  {'id': 'https://openalex.org/V969433497', 'iss...  journal-article
#
#                                          open_access  ...  \
# 0  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 1  {'is_oa': True, 'oa_status': 'green', 'oa_url'...  ...
# 2  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...  ...
# 0  {'is_oa': True, 'oa_status': 'green', 'oa_url'...  ...
# 1  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...  ...
#
#                              abstract_inverted_index  \
# 0  {'In': [0, 30, 88], '2015,': [1], 'five': [2, ...
# 1  {'This': [0], 'document': [1], 'presents': [2]...
# 2                                                NaN
# 0  {'Encephalitis': [0], 'is': [1], 'a': [2, 14, ...
# 1  {'There': [0, 88], 'is': [1, 128, 149], 'no': ...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'year': 2022, 'cited_by_count': 466}, {'year...
# 1  [{'year': 2022, 'cited_by_count': 500}, {'year...
# 2  [{'year': 2022, 'cited_by_count': 132}, {'year...
# 0  [{'year': 2022, 'cited_by_count': 259}, {'year...
# 1  [{'year': 2022, 'cited_by_count': 45}, {'year'...
#
#                  updated_date  created_date              first_author  \
# 0  2022-09-02T12:08:38.820533    2016-06-24              Mayank Goyal
# 1  2022-09-06T03:07:23.885671    2016-06-24         Ronald B. Postuma
# 2  2022-09-02T09:43:19.149729    2016-07-22              Adeera Levin
# 0  2022-09-01T04:18:12.009049    2016-06-24            Francesc Graus
# 1  2022-09-07T09:57:34.467656    2016-06-24  Leocadio Rodríguez-Mañas
#
#                         first_auth_orcid  \
# 0  https://orcid.org/0000-0001-9060-2109
# 1  https://orcid.org/0000-0002-6468-4734
# 2                                    NaN
# 0  https://orcid.org/0000-0002-8924-8322
# 1  https://orcid.org/0000-0002-6551-1333
#
#                                      first_auth_inst first_auth_country  \
# 0                              University of Calgary                 CA
# 1                          Montreal General Hospital                 CA
# 2                     University of British Columbia                 CA
# 0  Consorci Institut D'Investigacions Biomediques...                 ES
# 1                   Hospital Universitario de Getafe                 ES
#
#                            collaborators_of_interest
# 0  {'Antoni Dávalos': {'col_auth_orcid': 'https:/...
# 1  {'Jose A. Obeso': {'col_auth_orcid': None, 'co...
# 2  {'Alm deFrancisco': {'col_auth_orcid': None, '...
# 0  {'Susanne M. Benseler': {'col_auth_orcid': 'ht...
# 1  {'Howard Bergman': {'col_auth_orcid': None, 'c...
#
# [5 rows x 31 columns]

# %% [markdown]
# Surface concepts related to each publication:

# %%
concepts_ = df_tot.iloc[0]['concepts']
concepts = ast.literal_eval(concepts_)

# %%
len(concepts)
# Out:
# 14

# %%
concepts[0]
# Out:
# {'id': 'https://openalex.org/C71924100',
#  'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#  'display_name': 'Medicine',
#  'level': 0,
#  'score': '0.88283634'}

# %%
for concept in concepts:
    print(concept['display_name'])
# Out:
# Medicine
# Stroke (engine)
# Modified Rankin Scale
# Population
# Meta-analysis
# Randomized controlled trial
# Odds ratio
# Clinical trial
# Occlusion
# Random effects model
# Internal medicine
# Logistic regression
# Physical therapy
# Emergency medicine

# %%
df_concepts = pd.DataFrame()
ind = 0
for i in range(0, len(df_tot)):
    pub_id = df_tot.iloc[i]['id']
    
    #Get concepts
    concepts_ = df_tot.iloc[i]['concepts']
    concepts = ast.literal_eval(concepts_)
    for j in range(0, len(concepts)):
        ind+=1
        row = pd.DataFrame(data={
            'pub_id': pub_id,
            'concept': concepts[j]['display_name'],
            'concept_id': concepts[j]['id'],
            'concept_level': concepts[j]['level']
        }, index=[ind])
        df_concepts = pd.concat([df_concepts, row])

# %%
df_concepts['concept'] = df_concepts['concept'].str.lower()
df_concepts
# Out:
#                                 pub_id                concept  \
# 1     https://openalex.org/W2277258071               medicine
# 2     https://openalex.org/W2277258071        stroke (engine)
# 3     https://openalex.org/W2277258071  modified rankin scale
# 4     https://openalex.org/W2277258071             population
# 5     https://openalex.org/W2277258071          meta-analysis
# ...                                ...                    ...
# 1114  https://openalex.org/W2888310913     multiple sclerosis
# 1115  https://openalex.org/W2888310913               medicine
# 1116  https://openalex.org/W2888310913         adverse effect
# 1117  https://openalex.org/W2888310913             immunology
# 1118  https://openalex.org/W2888310913      internal medicine
#
#                             concept_id  concept_level
# 1       https://openalex.org/C71924100              0
# 2     https://openalex.org/C2780645631              2
# 3     https://openalex.org/C2780931571              4
# 4     https://openalex.org/C2908647359              2
# 5       https://openalex.org/C95190672              2
# ...                                ...            ...
# 1114  https://openalex.org/C2780640218              2
# 1115    https://openalex.org/C71924100              0
# 1116   https://openalex.org/C197934379              2
# 1117   https://openalex.org/C203014093              1
# 1118   https://openalex.org/C126322002              1
#
# [1118 rows x 4 columns]

# %%
df_concepts.to_csv(dataDir + 'concepts_by_pub_can_esp_first_auth.csv', index=False)

# %% [markdown]
# Find publications with concepts relevant to foreign policy and Canada-Spain relations:

# %%
df_concepts = pd.read_csv(dataDir + 'concepts_by_pub_can_esp_first_auth.csv')
df_concepts
# Out:
#                                 pub_id                concept  \
# 0     https://openalex.org/W2277258071               medicine
# 1     https://openalex.org/W2277258071        stroke (engine)
# 2     https://openalex.org/W2277258071  modified rankin scale
# 3     https://openalex.org/W2277258071             population
# 4     https://openalex.org/W2277258071          meta-analysis
# ...                                ...                    ...
# 1113  https://openalex.org/W2888310913     multiple sclerosis
# 1114  https://openalex.org/W2888310913               medicine
# 1115  https://openalex.org/W2888310913         adverse effect
# 1116  https://openalex.org/W2888310913             immunology
# 1117  https://openalex.org/W2888310913      internal medicine
#
#                             concept_id  concept_level
# 0       https://openalex.org/C71924100              0
# 1     https://openalex.org/C2780645631              2
# 2     https://openalex.org/C2780931571              4
# 3     https://openalex.org/C2908647359              2
# 4       https://openalex.org/C95190672              2
# ...                                ...            ...
# 1113  https://openalex.org/C2780640218              2
# 1114    https://openalex.org/C71924100              0
# 1115   https://openalex.org/C197934379              2
# 1116   https://openalex.org/C203014093              1
# 1117   https://openalex.org/C126322002              1
#
# [1118 rows x 4 columns]

# %%
df_concepts.loc[df_concepts['concept'].str.contains('foreign')]
# Out:
# Empty DataFrame
# Columns: [pub_id, concept, concept_id, concept_level]
# Index: []

# %% [markdown]
# Using a variety of search terms, there do not seem to be any publications with concepts-of-interest to foreign policy and Canada-Spain relations.
#
# Broaden search to publications with a spanish first author, and then to publications with Spanish collaborator.

# %% [markdown]
# #

# %% [markdown]
# #### Publications with Spanish first author

# %% [markdown]
# Query yearly batches, for the last 5 years. Isolate those publications with Spanish first authors.

# %%
endpoint = 'works'
filters = ['institutions.country_code:ES', 'publication_year:2022'] #'publication_year:>2017'
save_filename = 'works_esp_first_auth_2022.csv'
batch_size = 10

start = time.time()

#Start cursor pagination
filtered_works_url = construct_query_string_cursor(endpoint=endpoint, filters=filters)
response = requests.get(filtered_works_url)
response_count = response.json()['meta']['count']
print('Total number of results: ' + str(response_count))
pages = round(np.floor(response_count/200))
remainder = np.remainder(response_count, 200)
print('Processing ' + str(pages) + ' additional pages...')
df_response = pd.DataFrame(response.json()['results'])
df_esp = isolate_esp_first_auth_pubs(df_response)
df_esp.to_csv(dataDir + save_filename, index=False)
next_cursor = response.json()['meta']['next_cursor']

#Process batches of pages
batches = round(np.floor(pages/batch_size))
batch_remainder = np.remainder(pages, batch_size)

#Loop through pages in batch
for i in range(0, batches):
    df_batch = pd.DataFrame()
    for j in range(0, batch_size):
        filtered_works_url = construct_query_string_cursor(endpoint=endpoint, filters=filters, cursor=next_cursor)
        response = requests.get(filtered_works_url)
        df_response = pd.DataFrame(response.json()['results'])
        df_resp_proc = isolate_esp_first_auth_pubs(df_response)
        df_batch = pd.concat([df_batch, df_resp_proc])
        next_cursor = response.json()['meta']['next_cursor']
    df_esp_load = pd.read_csv(dataDir + save_filename)
    df_esp = pd.concat([df_esp_load, df_batch])
    df_esp.to_csv(dataDir + save_filename, index=False)
        
#Loop through pages in final batch
df_batch = pd.DataFrame()
for i in range(0, batch_remainder):
    filtered_works_url = construct_query_string_cursor(endpoint=endpoint, filters=filters, cursor=next_cursor)
    response = requests.get(filtered_works_url)
    df_response = pd.DataFrame(response.json()['results'])
    df_resp_proc = isolate_esp_first_auth_pubs(df_response)
    df_batch = pd.concat([df_batch, df_resp_proc])
    next_cursor = response.json()['meta']['next_cursor']
df_esp_load = pd.read_csv(dataDir + save_filename)
df_esp = pd.concat([df_esp_load, df_batch])
df_esp.to_csv(dataDir + save_filename, index=False)
    
end = time.time()   
t = end - start
print('Runtime: ' + str(round(t/60, 1)) + ' min')
# Out:
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=*
# Total number of results: 72807
# Processing 364 additional pages...
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlsxMiwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1c0MjA1MDkxODkwJ10i
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=Ils4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMTcwNDYyNTEnXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=Ils3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMTMzMzUxOTQnXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=Ils2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMTQ
XSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTQ2MDY4OTknXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTQ2ODM2NDknXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTQ3NzAzOTknXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTQ4OTE2NzcnXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTQ5ODM0NzUnXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTUwNjM0OTEnXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTUxMzU2MDcnXSI=
# https://api.openalex.org/works?mailto=naidoo@ualberta.ca&filter=institutions.country_code:ES,publication_year:2022&per-page=200&cursor=IlswLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyOTUyNjk4MDInXSI=
# Runtime: 16.9 min

# %% [markdown]
# #

# %% [markdown]
# Further process data, as yearly batches:

# %%
for file in os.listdir(dataDir + 'works_esp_first_auth/'):
    if 'works_esp_first_auth_' in file:
        print('Processing... ' + file)
        df1 = pd.read_csv(dataDir + 'works_esp_first_auth/' + file)
        df1['first_author'] = pd.Series()
        df1['first_auth_orcid'] = pd.Series()
        df1['first_auth_inst'] = pd.Series()
        df1['first_auth_country'] = pd.Series()
        df1['collaborators_of_interest'] = pd.Series()
        
        for i in range(0, len(df1)):
            auth_list_ = df1.iloc[i]['authorships']
            auth_list = ast.literal_eval(auth_list_)

            #Get first author details
            if auth_list[0]['author_position'] == 'first':
                if len(auth_list[0]['institutions'][0]) > 0:
                    if auth_list[0]['institutions'][0]['country_code'] == 'ES':
                        first_auth = auth_list[0]['author']['display_name']
                        first_auth_orcid = auth_list[0]['author']['orcid']
                        first_auth_inst = auth_list[0]['institutions'][0]['display_name']
                        first_auth_country = auth_list[0]['institutions'][0]['country_code']

            #Get collaborator authors' details
            collab_list = {}
            df_collabs = pd.DataFrame()
            for auth in auth_list:
                for inst in auth['institutions']:
                    if len(inst) > 0:
                        if inst['country_code'] == 'CA':
                            col_auth = auth['author']['display_name']
                            col_auth_orcid = auth['author']['orcid']
                            col_auth_inst = inst['display_name']
                            col_auth_country = inst['country_code']
                            col_auth_dict = {
                                'col_auth_orcid': col_auth_orcid,
                                'col_auth_inst': col_auth_inst,
                                'col_auth_country': col_auth_country
                            }
                            collab_list[col_auth] = col_auth_dict

            #Add columns
            df1.iloc[i,26] = first_auth
            df1.iloc[i,27] = first_auth_orcid
            df1.iloc[i,28] = first_auth_inst
            df1.iloc[i,29] = first_auth_country
            df1.iloc[i,30] = str(collab_list)
    
        df1.to_csv(dataDir + 'works_esp_first_auth/' + file[:-4] + '_proc.csv', index=False)
# Out:
# Processing... works_esp_first_auth_2017.csv
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_author'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_orcid'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_inst'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_country'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['collaborators_of_interest'] = pd.Series()
# Processing... works_esp_first_auth_2018.csv
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_author'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_orcid'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_inst'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_country'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['collaborators_of_interest'] = pd.Series()
# Processing... works_esp_first_auth_2019.csv
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_author'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_orcid'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_inst'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_country'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['collaborators_of_interest'] = pd.Series()
# Processing... works_esp_first_auth_2021.csv
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_author'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_orcid'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_inst'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_country'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['collaborators_of_interest'] = pd.Series()
# Processing... works_esp_first_auth_2020.csv
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_author'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_orcid'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_inst'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_country'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['collaborators_of_interest'] = pd.Series()
# Processing... works_esp_first_auth_2022.csv
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_author'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_orcid'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_inst'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['first_auth_country'] = pd.Series()
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_57710/2150122947.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df1['collaborators_of_interest'] = pd.Series()

# %% [markdown]
# #
