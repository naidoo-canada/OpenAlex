# %% [markdown]
# # Canada-IE Academic Collaborations
#
# #### Updated: Sep 23, 2022

# %% [markdown]
# #

# %% [markdown]
# Chris Berzins: "Could you do a search for Canadian academic collaboration with “IE University” (previously known an “Instituto Empresa”)? I don’t suspect there is a lot, if any, first author collaboration, so would be good to go broader. If anything much comes up, I’d like to send it to the Dean/Provost who I met yesterday, and discussed our project with."
#
# - IE first authors, Canadian collaborators
# - Canadian first authors, IE collaborators
#
# Ultimatley, generalize this for all regions.

# %%
import pandas as pd
import numpy as np
import ast

# %%
dataDir = '/Users/rnaidoo/Documents/Canada-Secure/GAC/2022_MDRID/Projects_data/OpenAlex/'

# %% [markdown]
# #

# %% [markdown]
# #### Functions:

# %%
def search_institutions(df_pubs, inst_search_terms=[]):
    
    inst_search_results = []
    for search_term in inst_search_terms:
        inst_search_results = inst_search_results + list(df_pubs.loc[df_pubs['first_auth_inst'].str.contains(search_term)]['first_auth_inst'].unique())
    df_insts = pd.DataFrame({'inst_search': inst_search_results})
    
    df_pubs2 = df_pubs.merge(df_insts, how='inner', left_on='first_auth_inst', right_on='inst_search')
    
    return [df_insts, df_pubs2]

# %%
def top_collab_Can(df_pubs, reg_name, dataDir_save, top=100):
    
    df_can_col = df_pubs.loc[df_pubs['collaborators_of_interest'] != '{}']
    
    df_result = df_can_col[['first_author', 'first_auth_inst', 'title', 'publication_date', 'cited_by_count', 'collaborators_of_interest', 'first_auth_orcid', 'id']]
    df_result = df_result.sort_values(['cited_by_count', 'publication_date'], ascending=[False, False]).reset_index(drop=True)
    df_result = df_result.drop_duplicates(subset=['id'], keep='first')
    print(str(len(df_result)) + ' unique papers retrieved.')
    df_result = df_result.rename(columns={
        'first_author': 'Spanish Researcher',
        'first_auth_inst': 'Institution',
        'title': 'Publication Title',
        'publication_date': 'Publication Date',
        'cited_by_count': 'Citation Count',
        'collaborators_of_interest': 'Canadian Collaborators',
        'first_auth_orcid': 'Academic Profile (ORCID)',
        'id': 'Publication Profile'
    })
    df_result = df_result.replace(np.nan, '')

    #Process Canadian Collaborators
    for i in range(0, len(df_result)):
        collab_dict_ = df_result['Canadian Collaborators'].iloc[i]
        if collab_dict_ != 'N':
            collab_dict = ast.literal_eval(collab_dict_)
            if len(collab_dict) > 0:
                collab_str = ''
                for auth in collab_dict:
                    if collab_str != '':
                        collab_str += ', '
                    collab_str += auth + ' (' + collab_dict[auth]['col_auth_inst']
                    if collab_dict[auth]['col_auth_orcid'] == None:
                        collab_str += ')'
                    else: 
                        collab_str += ', ' + collab_dict[auth]['col_auth_orcid'] + ')'
                df_result.iloc[i,5] = collab_str
    
    #Write results to Excel spreadsheet
    write_pubs_by_top_collab_Can(df_result=df_result, dataDir_save=dataDir_save, fn_prefix=reg_name+'_')
    
    #Produce summary table
    df_can_col['publications'] = 1
    df_top_ac = df_can_col[['cited_by_count', 'publications', 'first_author']].groupby(['first_author']).sum()
    df_top_ac = df_top_ac.sort_values('cited_by_count', ascending=False)
    df_top_ac2 = df_top_ac.merge(df_pubs[['first_author', 'first_auth_inst', 'first_auth_orcid']], how='left', on='first_author')
    df_top_ac2 = df_top_ac2.replace(np.nan, '')
    df_top_ac2 = df_top_ac2.rename(columns={
        'cited_by_count': 'by citations',
        'publications': 'by publications',
        'first_auth_inst': 'institution',
        'first_auth_orcid': 'orcid'
    })
    df_top_ac2 = df_top_ac2.drop_duplicates(subset=['orcid'])
    df_top_ac2 = df_top_ac2.drop_duplicates(subset=['first_author'])
    df_top_ac2 = df_top_ac2.set_index('first_author')
    if len(df_top_ac2) < top:
        top = len(df_top_ac2)
    df_top_ac2.index.names = ['Top-' + str(top) + ' academics in ' + reg_name + ' that collaborate with Canadian researchers']
    
    return df_top_ac2.head(top)

# %%
def write_pubs_by_top_collab_Can(df_result, dataDir_save, fn_prefix=''):

    sheet_name_ = 'top-pubs with Canadian collab'
    writer = pd.ExcelWriter(dataDir_save + fn_prefix + 'works_can_col.xlsx')
    df_result.to_excel(writer, sheet_name=sheet_name_, index=False)
    # Auto-adjust columns' width
    for column in df_result:
        if column == 'Publication Title':
            column_width = 100
        elif column == 'Canadian Collaborators':
            column_width = 75
        else:
            column_width = max(df_result[column].astype(str).map(len).max(), len(column))
        col_idx = df_result.columns.get_loc(column)
        writer.sheets[sheet_name_].set_column(col_idx, col_idx, column_width)

    writer.save()

# %% [markdown]
# #

# %% [markdown]
# #### Find IE first authors, with Canadian collaborators:

# %%
df_pubs = pd.read_csv(dataDir + 'works_ES_first_auth/' + 'works_ES_first_auth_since2017.csv')
print(len(df_pubs))
df_pubs.head()
# Out:
# 458602
#                                  id  \
# 0  https://openalex.org/W2963641747
# 1  https://openalex.org/W2472444605
# 2  https://openalex.org/W2478043544
# 3  https://openalex.org/W2482508491
# 4  https://openalex.org/W2484989076
#
#                                                  doi  \
# 0                                                NaN
# 1  https://doi.org/10.1061/(asce)ei.1943-5541.000...
# 2         https://doi.org/10.1016/j.rpsm.2016.04.002
# 3       https://doi.org/10.1016/j.spinee.2016.08.007
# 4        https://doi.org/10.1007/978-3-319-09096-2_9
#
#                                                title  \
# 0  Joan Marcet e Lucía Medina (eds.), La política...
# 1  Developing Topographic Surveying Software to T...
# 2  Inducción de hipocapnia e hiperoxia con maniob...
# 3  Preoperative and postoperative sagittal plane ...
# 4        Looking Into the Profile of Music Audiences
#
#                                         display_name  publication_year  \
# 0  Joan Marcet e Lucía Medina (eds.), La política...              2017
# 1  Developing Topographic Surveying Software to T...              2017
# 2  Inducción de hipocapnia e hiperoxia con maniob...              2017
# 3  Preoperative and postoperative sagittal plane ...              2017
# 4        Looking Into the Profile of Music Audiences              2017
#
#   publication_date                                                ids  \
# 0       2017-01-01  {'openalex': 'https://openalex.org/W2963641747...
# 1       2017-01-01  {'openalex': 'https://openalex.org/W2472444605...
# 2       2017-01-01  {'openalex': 'https://openalex.org/W2478043544...
# 3       2017-01-01  {'openalex': 'https://openalex.org/W2482508491...
# 4       2017-01-01  {'openalex': 'https://openalex.org/W2484989076...
#
#                                           host_venue             type  \
# 0  {'id': None, 'issn_l': None, 'issn': None, 'di...              NaN
# 1  {'id': 'https://openalex.org/V170370859', 'iss...  journal-article
# 2  {'id': 'https://openalex.org/V2898614270', 'is...  journal-article
# 3  {'id': 'https://openalex.org/V112180307', 'iss...  journal-article
# 4  {'id': 'https://openalex.org/V3121261024', 'is...     book-chapter
#
#                                          open_access  ...  \
# 0  {'is_oa': False, 'oa_status': None, 'oa_url': ...  ...
# 1  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 2  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 3  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 4  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
#
#                              abstract_inverted_index  \
# 0                                                NaN
# 1  {'AbstractIn': [0], 'this': [1], 'study,': [2]...
# 2  {'Resumen': [0], 'Introduccion': [3], 'La': [5...
# 3  {'Abstract': [0], 'Background': [3], 'Context'...
# 4  {'The': [0], 'main': [1, 98], 'aims': [2], 'of...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0                                                 []
# 1  [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 2  [{'year': 2021, 'cited_by_count': 1}, {'year':...
# 3  [{'year': 2021, 'cited_by_count': 2}, {'year':...
# 4  [{'year': 2022, 'cited_by_count': 1}, {'year':...
#
#                  updated_date created_date             first_author  \
# 0  2022-08-08T10:54:07.500056   2019-07-30             Steven Forti
# 1  2022-08-09T14:16:07.295905   2016-07-22     Miguel Castro-García
# 2  2022-08-22T06:24:56.670484   2016-08-23     Aida de Arriba-Arnau
# 3                  2022-06-24   2016-08-23  Felisa Sánchez-Mariscal
# 4  2022-08-08T13:09:36.373379   2016-08-23  Víctor Fernández-Blanco
#
#                         first_auth_orcid                   first_auth_inst  \
# 0  https://orcid.org/0000-0002-7027-0220             Instituto de Historia
# 1  https://orcid.org/0000-0003-4157-6164  University of Castilla-La Mancha
# 2  https://orcid.org/0000-0002-7877-7341           University of Barcelona
# 3                                    NaN  Hospital Universitario de Getafe
# 4  https://orcid.org/0000-0003-2096-9460              University of Oviedo
#
#   first_auth_country collaborators_of_interest
# 0                 ES                        {}
# 1                 ES                        {}
# 2                 ES                        {}
# 3                 ES                        {}
# 4                 ES                        {}
#
# [5 rows x 31 columns]

# %%
reg_name = 'IE'

dataDir_reg = dataDir+'Regional/'+reg_name+'/'

# %%
inst_search_terms = [
    'IE',
    'Instituto Empresa'
]

df_insts, df_pubs_reg = search_institutions(df_pubs=df_pubs, inst_search_terms=inst_search_terms)
df_insts['inst_search'].unique()
# Out:
# array(['IE University'], dtype=object)

# %%
top_collab_Can(df_pubs=df_pubs_reg, reg_name=reg_name, dataDir_save=dataDir_reg)
# Out:
# 22 unique papers retrieved.
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_18110/2934749720.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_can_col['publications'] = 1
#                                                     by citations  \
# Top-5 academics in IE that collaborate with Can...
# Mikko Ketokivi                                               169
# Alvaro E. Arenas                                              34
# Stefanie Beninger                                             32
# Chrystelle Sola                                                6
# Kyle John Wilby                                                0
#
#                                                     by publications  \
# Top-5 academics in IE that collaborate with Can...
# Mikko Ketokivi                                                    2
# Alvaro E. Arenas                                                  2
# Stefanie Beninger                                                 4
# Chrystelle Sola                                                   1
# Kyle John Wilby                                                   1
#
#                                                       institution  \
# Top-5 academics in IE that collaborate with Can...
# Mikko Ketokivi                                      IE University
# Alvaro E. Arenas                                    IE University
# Stefanie Beninger                                   IE University
# Chrystelle Sola                                     IE University
# Kyle John Wilby                                     IE University
#
#                                                                                     orcid
# Top-5 academics in IE that collaborate with Can...
# Mikko Ketokivi                                      https://orcid.org/0000-0003-4510-4949
# Alvaro E. Arenas                                    https://orcid.org/0000-0003-1183-1283
# Stefanie Beninger                                   https://orcid.org/0000-0002-6956-7625
# Chrystelle Sola                                     https://orcid.org/0000-0002-8375-9121
# Kyle John Wilby                                     https://orcid.org/0000-0002-1670-2512

# %% [markdown]
# #

# %% [markdown]
# #### Find Canadian first authors, with IE collaborators:

# %%
df_pubs = pd.read_csv(dataDir + 'works_CA_first_auth/' + 'works_CA_first_auth_since2017.csv')
print(len(df_pubs))
df_pubs.head()
# Out:
# 506581
#                                  id  \
# 0  https://openalex.org/W2582434976
# 1  https://openalex.org/W2598730797
# 2  https://openalex.org/W2523535834
# 3  https://openalex.org/W2940082676
# 4  https://openalex.org/W2732588845
#
#                                             doi  \
# 0  https://doi.org/10.1007/978-1-4842-2598-1_12
# 1    https://doi.org/10.1109/iccnc.2017.7876167
# 2   https://doi.org/10.1007/978-3-319-42304-3_1
# 3                                           NaN
# 4  https://doi.org/10.1161/strokeaha.117.017622
#
#                                                title  \
# 0                              Using Resource Quotas
# 1  An improved SDN-based fabric for flexible data...
# 2  Power-Shaping Configurable Microprocessors for...
# 3  Les contours de l'organisation du travail soum...
# 4                             In-Patient Code Stroke
#
#                                         display_name  publication_year  \
# 0                              Using Resource Quotas              2017
# 1  An improved SDN-based fabric for flexible data...              2017
# 2  Power-Shaping Configurable Microprocessors for...              2017
# 3  Les contours de l'organisation du travail soum...              2017
# 4                             In-Patient Code Stroke              2017
#
#   publication_date                                                ids  \
# 0       2017-01-01  {'openalex': 'https://openalex.org/W2582434976...
# 1       2017-01-01  {'openalex': 'https://openalex.org/W2598730797...
# 2       2017-01-01  {'openalex': 'https://openalex.org/W2523535834...
# 3       2017-01-01  {'openalex': 'https://openalex.org/W2940082676...
# 4       2017-01-01  {'openalex': 'https://openalex.org/W2732588845...
#
#                                           host_venue                 type  \
# 0  {'id': None, 'issn_l': None, 'issn': None, 'di...         book-chapter
# 1  {'id': None, 'issn_l': None, 'issn': None, 'di...  proceedings-article
# 2  {'id': None, 'issn_l': None, 'issn': None, 'di...         book-chapter
# 3  {'id': None, 'issn_l': None, 'issn': None, 'di...                  NaN
# 4  {'id': 'https://openalex.org/V62532593', 'issn...      journal-article
#
#                                          open_access  ...  \
# 0  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 1  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 2  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 3  {'is_oa': False, 'oa_status': None, 'oa_url': ...  ...
# 4  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...  ...
#
#                              abstract_inverted_index  \
# 0  {'In': [0], 'Chapter': [1], '10': [2], 'we': [...
# 1  {'Data': [0], 'centers': [1], 'play': [2], 'an...
# 2  {'The': [0], '“Internet': [1], 'of': [2, 8, 52...
# 3                                                NaN
# 4  {'Stroke': [0], 'is': [1], 'a': [2], 'relative...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0                                                 []
# 1              [{'year': 2020, 'cited_by_count': 1}]
# 2                                                 []
# 3                                                 []
# 4  [{'year': 2022, 'cited_by_count': 5}, {'year':...
#
#                  updated_date created_date            first_author  \
# 0                  2022-06-30   2017-02-03            Deepak Vohra
# 1  2022-08-22T07:21:54.950801   2017-04-07                 Wei Hou
# 2  2022-08-18T08:44:40.666311   2016-09-30             Fabio Campi
# 3  2022-08-07T09:01:08.519143   2019-04-25             Marc Nihoul
# 4  2022-08-30T10:39:20.384673   2017-07-14  Charles D. Kassardjian
#
#                         first_auth_orcid                  first_auth_inst  \
# 0                                    NaN              Peace Arch Hospital
# 1                                    NaN             University of Ottawa
# 2                                    NaN          Simon Fraser University
# 3                                    NaN  Université Laval Faculty of Law
# 4  https://orcid.org/0000-0001-7117-8787            University of Toronto
#
#   first_auth_country collaborators_of_interest
# 0                 CA                        {}
# 1                 CA                        {}
# 2                 CA                        {}
# 3                 CA                        {}
# 4                 CA                        {}
#
# [5 rows x 31 columns]

# %%
df_pubs_esp_col = df_pubs.loc[df_pubs['collaborators_of_interest'] != '{}']
print(len(df_pubs_esp_col))
df_pubs_esp_col.head()
# Out:
# 3504
#                                     id  \
# 234   https://openalex.org/W2915281934
# 459   https://openalex.org/W2562287101
# 1560  https://openalex.org/W2342386562
# 1951  https://openalex.org/W2273470132
# 2474  https://openalex.org/W2474041279
#
#                                                 doi  \
# 234                                             NaN
# 459     https://doi.org/10.1183/13993003.e0016-2016
# 1560      https://doi.org/10.1007/s10494-016-9737-2
# 1951  https://doi.org/10.1016/j.jpubeco.2016.10.002
# 2474    https://doi.org/10.1016/j.proci.2016.06.119
#
#                                                   title  \
# 234   Stereotactic radiosurgery for vestibular schwa...
# 459   Executive Summary: 2017 ERS/ATS standards for ...
# 1560  Coherent Structures in a Non-equilibrium Large...
# 1951  Compulsory voting, turnout, and government spe...
# 2474  Structural effects of biodiesel on soot format...
#
#                                            display_name  publication_year  \
# 234   Stereotactic radiosurgery for vestibular schwa...              2017
# 459   Executive Summary: 2017 ERS/ATS standards for ...              2017
# 1560  Coherent Structures in a Non-equilibrium Large...              2017
# 1951  Compulsory voting, turnout, and government spe...              2017
# 2474  Structural effects of biodiesel on soot format...              2017
#
#      publication_date                                                ids  \
# 234        2017-01-01  {'openalex': 'https://openalex.org/W2915281934...
# 459        2017-01-01  {'openalex': 'https://openalex.org/W2562287101...
# 1560       2017-01-01  {'openalex': 'https://openalex.org/W2342386562...
# 1951       2017-01-01  {'openalex': 'https://openalex.org/W2273470132...
# 2474       2017-01-01  {'openalex': 'https://openalex.org/W2474041279...
#
#                                              host_venue             type  \
# 234   {'id': None, 'issn_l': None, 'issn': None, 'di...              NaN
# 459   {'id': 'https://openalex.org/V4210207896', 'is...  journal-article
# 1560  {'id': 'https://openalex.org/V4210200752', 'is...  journal-article
# 1951  {'id': 'https://openalex.org/V199447588', 'iss...  journal-article
# 2474  {'id': 'https://openalex.org/V4210174958', 'is...  journal-article
#
#                                             open_access  ...  \
# 234   {'is_oa': False, 'oa_status': None, 'oa_url': ...  ...
# 459   {'is_oa': True, 'oa_status': 'bronze', 'oa_url...  ...
# 1560  {'is_oa': True, 'oa_status': 'green', 'oa_url'...  ...
# 1951  {'is_oa': True, 'oa_status': 'bronze', 'oa_url...  ...
# 2474  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
#
#                                 abstract_inverted_index  \
# 234   {'Objectives': [0], 'The': [1, 86], 'aim': [2]...
# 459   {'This': [0], 'document': [1], 'summarises': [...
# 1560  {'The': [0, 19, 53, 147, 220], 'characteristic...
# 1951  {'Abstract': [0], 'We': [3], 'study': [4], 'a'...
# 2474  {'Abstract': [0], 'Structural': [3], 'effects'...
#
#                                        cited_by_api_url  \
# 234   https://api.openalex.org/works?filter=cites:W2...
# 459   https://api.openalex.org/works?filter=cites:W2...
# 1560  https://api.openalex.org/works?filter=cites:W2...
# 1951  https://api.openalex.org/works?filter=cites:W2...
# 2474  https://api.openalex.org/works?filter=cites:W2...
#
#                                          counts_by_year  \
# 234   [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 459   [{'year': 2022, 'cited_by_count': 2}, {'year':...
# 1560  [{'year': 2022, 'cited_by_count': 2}, {'year':...
# 1951  [{'year': 2022, 'cited_by_count': 3}, {'year':...
# 2474  [{'year': 2022, 'cited_by_count': 9}, {'year':...
#
#                     updated_date created_date      first_author  \
# 234   2022-09-12T07:48:22.394298   2019-03-02       May N. Tsao
# 459   2022-09-03T06:43:42.662189   2017-01-06   Brian L. Graham
# 1560  2022-09-06T07:41:49.345081   2016-06-24       Yvan Maciel
# 1951  2022-09-20T09:24:42.941174   2016-06-24  Mitchell Hoffman
# 2474  2022-09-14T20:38:19.828906   2016-07-22    Chiara Saggese
#
#                            first_auth_orcid                  first_auth_inst  \
# 234                                     NaN  Princess Margaret Cancer Centre
# 459                                     NaN       University of Saskatchewan
# 1560  https://orcid.org/0000-0003-1993-472X                 Université Laval
# 1951                                    NaN            University of Toronto
# 2474  https://orcid.org/0000-0002-4043-1054            University of Toronto
#
#      first_auth_country                          collaborators_of_interest
# 234                  CA  {'Roberto Martinez': {'col_auth_orcid': 'https...
# 459                  CA  {'Felip Burgos': {'col_auth_orcid': 'https://o...
# 1560                 CA  {'Mark P. Simens': {'col_auth_orcid': None, 'c...
# 1951                 CA  {'Gianmarco León': {'col_auth_orcid': 'https:/...
# 2474                 CA  {'Javier Barba': {'col_auth_orcid': None, 'col...
#
# [5 rows x 31 columns]

# %%
df_pubs_esp_col['collaborators_of_interest'].iloc[0]
# Out:
# "{'Roberto Martinez': {'col_auth_orcid': 'https://orcid.org/0000-0001-7342-9332', 'col_auth_inst': 'Hospital Ruber Internacional', 'col_auth_country': 'ES'}}"

# %%
IE_col_indicies = []
for i in range(0, len(df_pubs_esp_col)):
    collab_dict_ = df_pubs_esp_col['collaborators_of_interest'].iloc[i]
    collab_dict = ast.literal_eval(collab_dict_)
    if len(collab_dict) > 0:
        for auth in collab_dict:
            if collab_dict[auth]['col_auth_inst'] == 'IE University':
                IE_col_indicies.append(i) 
                
df_pubs_IE_col = df_pubs_esp_col.iloc[IE_col_indicies]

# %%
print(len(df_pubs_IE_col))
df_pubs_IE_col.head()
# Out:
# 16
#                                       id  \
# 44284   https://openalex.org/W3124864154
# 162492  https://openalex.org/W2801245079
# 230479  https://openalex.org/W2967825003
# 243732  https://openalex.org/W2987653376
# 265009  https://openalex.org/W2999020507
#
#                                                   doi  \
# 44284         https://doi.org/10.1111/1911-3846.12299
# 162492             https://doi.org/10.1111/joop.12221
# 230479        https://doi.org/10.2134/jeq2019.02.0070
# 243732      https://doi.org/10.2136/sssaj2019.03.0087
# 265009  https://doi.org/10.1080/0960085x.2019.1708821
#
#                                                     title  \
# 44284   Popularizing a Management Accounting Idea: The...
# 162492  How does proactive personality promote creativ...
# 230479  Options for Improved Phosphorus Cycling and Us...
# 243732  Spatial Variation of Soil Health Indices in a ...
# 265009  IT value creation in public sector: how IT-ena...
#
#                                              display_name  publication_year  \
# 44284   Popularizing a Management Accounting Idea: The...              2017
# 162492  How does proactive personality promote creativ...              2018
# 230479  Options for Improved Phosphorus Cycling and Us...              2019
# 243732  Spatial Variation of Soil Health Indices in a ...              2019
# 265009  IT value creation in public sector: how IT-ena...              2020
#
#        publication_date                                                ids  \
# 44284        2017-06-01  {'openalex': 'https://openalex.org/W3124864154...
# 162492       2018-12-01  {'openalex': 'https://openalex.org/W2801245079...
# 230479       2019-09-01  {'openalex': 'https://openalex.org/W2967825003...
# 243732       2019-11-01  {'openalex': 'https://openalex.org/W2987653376...
# 265009       2020-01-06  {'openalex': 'https://openalex.org/W2999020507...
#
#                                                host_venue             type  \
# 44284   {'id': 'https://openalex.org/V65924262', 'issn...  journal-article
# 162492  {'id': 'https://openalex.org/V87328381', 'issn...  journal-article
# 230479  {'id': 'https://openalex.org/V81083566', 'issn...  journal-article
# 243732  {'id': 'https://openalex.org/V59755854', 'issn...  journal-article
# 265009  {'id': 'https://openalex.org/V116712389', 'iss...  journal-article
#
#                                               open_access  ...  \
# 44284   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 162492  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 230479  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...  ...
# 243732  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 265009  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
#
#                                   abstract_inverted_index  \
# 44284   {'We': [0, 100], 'explore': [1], 'how': [2, 67...
# 162492                                                NaN
# 230479  {'Soil': [0], 'phosphorus': [1], '(P)': [2], '...
# 243732                                                NaN
# 265009  {'Governments': [0], 'today': [1], 'are': [2],...
#
#                                          cited_by_api_url  \
# 44284   https://api.openalex.org/works?filter=cites:W3...
# 162492  https://api.openalex.org/works?filter=cites:W2...
# 230479  https://api.openalex.org/works?filter=cites:W2...
# 243732  https://api.openalex.org/works?filter=cites:W2...
# 265009  https://api.openalex.org/works?filter=cites:W2...
#
#                                            counts_by_year  \
# 44284   [{'year': 2022, 'cited_by_count': 4}, {'year':...
# 162492  [{'year': 2022, 'cited_by_count': 4}, {'year':...
# 230479  [{'year': 2022, 'cited_by_count': 11}, {'year'...
# 243732  [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 265009  [{'year': 2022, 'cited_by_count': 7}, {'year':...
#
#                       updated_date created_date            first_author  \
# 44284   2022-08-18T20:04:36.345408   2021-02-01         David J. Cooper
# 162492  2022-08-18T17:59:54.620476   2018-05-17            Jingzhou Pan
# 230479  2022-09-18T11:01:02.692261   2019-08-22  Kimberley D. Schneider
# 243732  2022-08-24T06:24:44.634774   2019-11-22       Bernie J. Zebarth
# 265009  2022-09-16T17:47:56.155670   2020-01-23            Jie Mein Goh
#
#                              first_auth_orcid  \
# 44284                                     NaN
# 162492                                    NaN
# 230479                                    NaN
# 243732  https://orcid.org/0000-0003-1465-5051
# 265009  https://orcid.org/0000-0002-3067-0916
#
#                                 first_auth_inst first_auth_country  \
# 44284                     University of Alberta                 CA
# 162492      College of Management and Economics                 CA
# 230479  Agriculture and Agriculture-Food Canada                 CA
# 243732  Agriculture and Agriculture-Food Canada                 CA
# 265009                  Simon Fraser University                 CA
#
#                                 collaborators_of_interest
# 44284   {'Mahmoud Ezzamel': {'col_auth_orcid': None, '...
# 162492  {'Bin Ma': {'col_auth_orcid': None, 'col_auth_...
# 230479  {'Derek H. Lynch': {'col_auth_orcid': 'https:/...
# 243732  {'David L. Burton': {'col_auth_orcid': 'https:...
# 265009  {'Jie Mein Goh': {'col_auth_orcid': 'https://o...
#
# [5 rows x 31 columns]

# %%
#Process IE collaborators
for i in range(0, len(df_pubs_IE_col)):
    collab_dict_ = df_pubs_IE_col['collaborators_of_interest'].iloc[i]
    collab_dict = ast.literal_eval(collab_dict_)
    if len(collab_dict) > 0:
        collab_str = ''
        for auth in collab_dict:
            if collab_str != '':
                collab_str += ', '
            collab_str += auth + ' (' + collab_dict[auth]['col_auth_inst']
            if collab_dict[auth]['col_auth_orcid'] == None:
                collab_str += ')'
            else: 
                collab_str += ', ' + collab_dict[auth]['col_auth_orcid'] + ')'
        df_pubs_IE_col.iloc[i,-1] = collab_str

# %%
df_pubs_IE_col.head()
# Out:
#                                       id  \
# 44284   https://openalex.org/W3124864154
# 162492  https://openalex.org/W2801245079
# 230479  https://openalex.org/W2967825003
# 243732  https://openalex.org/W2987653376
# 265009  https://openalex.org/W2999020507
#
#                                                   doi  \
# 44284         https://doi.org/10.1111/1911-3846.12299
# 162492             https://doi.org/10.1111/joop.12221
# 230479        https://doi.org/10.2134/jeq2019.02.0070
# 243732      https://doi.org/10.2136/sssaj2019.03.0087
# 265009  https://doi.org/10.1080/0960085x.2019.1708821
#
#                                                     title  \
# 44284   Popularizing a Management Accounting Idea: The...
# 162492  How does proactive personality promote creativ...
# 230479  Options for Improved Phosphorus Cycling and Us...
# 243732  Spatial Variation of Soil Health Indices in a ...
# 265009  IT value creation in public sector: how IT-ena...
#
#                                              display_name  publication_year  \
# 44284   Popularizing a Management Accounting Idea: The...              2017
# 162492  How does proactive personality promote creativ...              2018
# 230479  Options for Improved Phosphorus Cycling and Us...              2019
# 243732  Spatial Variation of Soil Health Indices in a ...              2019
# 265009  IT value creation in public sector: how IT-ena...              2020
#
#        publication_date                                                ids  \
# 44284        2017-06-01  {'openalex': 'https://openalex.org/W3124864154...
# 162492       2018-12-01  {'openalex': 'https://openalex.org/W2801245079...
# 230479       2019-09-01  {'openalex': 'https://openalex.org/W2967825003...
# 243732       2019-11-01  {'openalex': 'https://openalex.org/W2987653376...
# 265009       2020-01-06  {'openalex': 'https://openalex.org/W2999020507...
#
#                                                host_venue             type  \
# 44284   {'id': 'https://openalex.org/V65924262', 'issn...  journal-article
# 162492  {'id': 'https://openalex.org/V87328381', 'issn...  journal-article
# 230479  {'id': 'https://openalex.org/V81083566', 'issn...  journal-article
# 243732  {'id': 'https://openalex.org/V59755854', 'issn...  journal-article
# 265009  {'id': 'https://openalex.org/V116712389', 'iss...  journal-article
#
#                                               open_access  ...  \
# 44284   {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 162492  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 230479  {'is_oa': True, 'oa_status': 'hybrid', 'oa_url...  ...
# 243732  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
# 265009  {'is_oa': False, 'oa_status': 'closed', 'oa_ur...  ...
#
#                                   abstract_inverted_index  \
# 44284   {'We': [0, 100], 'explore': [1], 'how': [2, 67...
# 162492                                                NaN
# 230479  {'Soil': [0], 'phosphorus': [1], '(P)': [2], '...
# 243732                                                NaN
# 265009  {'Governments': [0], 'today': [1], 'are': [2],...
#
#                                          cited_by_api_url  \
# 44284   https://api.openalex.org/works?filter=cites:W3...
# 162492  https://api.openalex.org/works?filter=cites:W2...
# 230479  https://api.openalex.org/works?filter=cites:W2...
# 243732  https://api.openalex.org/works?filter=cites:W2...
# 265009  https://api.openalex.org/works?filter=cites:W2...
#
#                                            counts_by_year  \
# 44284   [{'year': 2022, 'cited_by_count': 4}, {'year':...
# 162492  [{'year': 2022, 'cited_by_count': 4}, {'year':...
# 230479  [{'year': 2022, 'cited_by_count': 11}, {'year'...
# 243732  [{'year': 2022, 'cited_by_count': 1}, {'year':...
# 265009  [{'year': 2022, 'cited_by_count': 7}, {'year':...
#
#                       updated_date created_date            first_author  \
# 44284   2022-08-18T20:04:36.345408   2021-02-01         David J. Cooper
# 162492  2022-08-18T17:59:54.620476   2018-05-17            Jingzhou Pan
# 230479  2022-09-18T11:01:02.692261   2019-08-22  Kimberley D. Schneider
# 243732  2022-08-24T06:24:44.634774   2019-11-22       Bernie J. Zebarth
# 265009  2022-09-16T17:47:56.155670   2020-01-23            Jie Mein Goh
#
#                              first_auth_orcid  \
# 44284                                     NaN
# 162492                                    NaN
# 230479                                    NaN
# 243732  https://orcid.org/0000-0003-1465-5051
# 265009  https://orcid.org/0000-0002-3067-0916
#
#                                 first_auth_inst first_auth_country  \
# 44284                     University of Alberta                 CA
# 162492      College of Management and Economics                 CA
# 230479  Agriculture and Agriculture-Food Canada                 CA
# 243732  Agriculture and Agriculture-Food Canada                 CA
# 265009                  Simon Fraser University                 CA
#
#                                 collaborators_of_interest
# 44284                     Mahmoud Ezzamel (IE University)
# 162492                             Bin Ma (IE University)
# 230479  Derek H. Lynch (IE University, https://orcid.o...
# 243732  David L. Burton (IE University, https://orcid....
# 265009  Jie Mein Goh (IE University, https://orcid.org...
#
# [5 rows x 31 columns]

# %%
df_result = df_pubs_IE_col[['first_author', 'first_auth_inst', 'title', 'publication_date', 'cited_by_count', 'collaborators_of_interest', 'first_auth_orcid', 'id']]
df_result = df_result.sort_values(['cited_by_count', 'publication_date'], ascending=[False, False]).reset_index(drop=True)
df_result = df_result.drop_duplicates(subset=['id'], keep='first')
print(str(len(df_result)) + ' unique papers retrieved.')
df_result = df_result.rename(columns={
    'first_author': 'Canadian Researcher',
    'first_auth_inst': 'Institution',
    'title': 'Publication Title',
    'publication_date': 'Publication Date',
    'cited_by_count': 'Citation Count',
    'collaborators_of_interest': 'IE Collaborators',
    'first_auth_orcid': 'Academic Profile (ORCID)',
    'id': 'Publication Profile'
})
df_result = df_result.replace(np.nan, '')
# Out:
# 15 unique papers retrieved.

# %%
dataDir_save = dataDir_reg
sheet_name_ = 'top-pubs with IE collab'
writer = pd.ExcelWriter(dataDir_save + 'CA_works_IE_col.xlsx')
df_result.to_excel(writer, sheet_name=sheet_name_, index=False)
# Auto-adjust columns' width
for column in df_pubs_IE_col:
    if column == 'Publication Title':
        column_width = 100
    elif column == 'IE Collaborators':
        column_width = 75
    else:
        column_width = max(df_pubs_IE_col[column].astype(str).map(len).max(), len(column))
    col_idx = df_pubs_IE_col.columns.get_loc(column)
    writer.sheets[sheet_name_].set_column(col_idx, col_idx, column_width)

writer.save()

# %%
df_result.head()
# Out:
#       Canadian Researcher                              Institution  \
# 0         David J. Cooper                    University of Alberta
# 1  Kimberley D. Schneider  Agriculture and Agriculture-Food Canada
# 2            Jingzhou Pan      College of Management and Economics
# 3            Jie Mein Goh                  Simon Fraser University
# 5      Stanley J. Shapiro                  Simon Fraser University
#
#                                    Publication Title Publication Date  \
# 0  Popularizing a Management Accounting Idea: The...       2017-06-01
# 1  Options for Improved Phosphorus Cycling and Us...       2019-09-01
# 2  How does proactive personality promote creativ...       2018-12-01
# 3  IT value creation in public sector: how IT-ena...       2020-01-06
# 5  Macromarketing Pedagogy: Empowering Students t...       2021-03-01
#
#    Citation Count                                   IE Collaborators  \
# 0              63                    Mahmoud Ezzamel (IE University)
# 1              40  Derek H. Lynch (IE University, https://orcid.o...
# 2              24                             Bin Ma (IE University)
# 3              22  Jie Mein Goh (IE University, https://orcid.org...
# 5              10  Stefanie Beninger (IE University, https://orci...
#
#                 Academic Profile (ORCID)               Publication Profile
# 0                                         https://openalex.org/W3124864154
# 1                                         https://openalex.org/W2967825003
# 2                                         https://openalex.org/W2801245079
# 3  https://orcid.org/0000-0002-3067-0916  https://openalex.org/W2999020507
# 5  https://orcid.org/0000-0003-3013-2576  https://openalex.org/W3080720362

# %%
top = 10
df_pubs_IE_col['publications'] = 1
df_top_ac = df_pubs_IE_col[['cited_by_count', 'publications', 'first_author']].groupby(['first_author']).sum()
df_top_ac = df_top_ac.sort_values('cited_by_count', ascending=False)
df_top_ac2 = df_top_ac.merge(df_pubs[['first_author', 'first_auth_inst', 'first_auth_orcid']], how='left', on='first_author')
df_top_ac2 = df_top_ac2.replace(np.nan, '')
df_top_ac2 = df_top_ac2.rename(columns={
    'cited_by_count': 'by citations',
    'publications': 'by publications',
    'first_auth_inst': 'institution',
    'first_auth_orcid': 'orcid'
})
df_top_ac2 = df_top_ac2.drop_duplicates(subset=['orcid'])
df_top_ac2 = df_top_ac2.drop_duplicates(subset=['first_author'])
df_top_ac2 = df_top_ac2.set_index('first_author')
if len(df_top_ac2) < top:
    top = len(df_top_ac2)
df_top_ac2.index.names = ['Top-' + str(top) + ' academics in Canada that collaborate with IE researchers']

df_top_ac2.head(top)
# Out:
# /var/folders/_k/dq0rn3rs5438vj_0c6dwhhyr0000gn/T/ipykernel_18110/326304402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pubs_IE_col['publications'] = 1
#                                                     by citations  \
# Top-10 academics in Canada that collaborate wit...
# David J. Cooper                                               63
# Jie Mein Goh                                                  44
# Jingzhou Pan                                                  24
# Stanley J. Shapiro                                            10
# Bernie J. Zebarth                                              6
# William F. McIntyre                                            2
# Zhanna Lyubykh                                                 2
# Cody A. Freas                                                  0
# Daniel Richard Clark                                           0
# Karen Robson                                                   0
#
#                                                     by publications  \
# Top-10 academics in Canada that collaborate wit...
# David J. Cooper                                                   1
# Jie Mein Goh                                                      2
# Jingzhou Pan                                                      1
# Stanley J. Shapiro                                                1
# Bernie J. Zebarth                                                 1
# William F. McIntyre                                               1
# Zhanna Lyubykh                                                    1
# Cody A. Freas                                                     1
# Daniel Richard Clark                                              1
# Karen Robson                                                      1
#
#                                                                                 institution  \
# Top-10 academics in Canada that collaborate wit...
# David J. Cooper                                                       University of Alberta
# Jie Mein Goh                                                        Simon Fraser University
# Jingzhou Pan                                            College of Management and Economics
# Stanley J. Shapiro                                                  Simon Fraser University
# Bernie J. Zebarth                                   Agriculture and Agriculture-Food Canada
# William F. McIntyre                                    Population Health Research Institute
# Zhanna Lyubykh                                                        University of Calgary
# Cody A. Freas                                                         University of Alberta
# Daniel Richard Clark                                                     Western University
# Karen Robson                                                          University of Windsor
#
#                                                                                     orcid
# Top-10 academics in Canada that collaborate wit...
# David J. Cooper
# Jie Mein Goh                                        https://orcid.org/0000-0002-3067-0916
# Jingzhou Pan                                        https://orcid.org/0000-0002-5484-7958
# Stanley J. Shapiro                                  https://orcid.org/0000-0003-3013-2576
# Bernie J. Zebarth                                   https://orcid.org/0000-0003-1465-5051
# William F. McIntyre                                 https://orcid.org/0000-0001-6082-7542
# Zhanna Lyubykh                                      https://orcid.org/0000-0002-6587-2200
# Cody A. Freas                                       https://orcid.org/0000-0001-7026-1255
# Daniel Richard Clark                                https://orcid.org/0000-0003-1645-4667
# Karen Robson                                        https://orcid.org/0000-0001-7933-3411
